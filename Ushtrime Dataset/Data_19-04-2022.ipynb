# %%
import pandas as pd

# %%
df=pd.read_csv('survey_results_public.csv', index_col='ResponseId')
schema_df=pd.read_csv('survey_results_schema.csv', index_col='qname')

# %%
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 50)

# %%
df.head()
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# 3                                          Student, full-time
# 4                                          Employed full-time
# 5           Independent contractor, freelancer, or self-em...
#
#                                                       Country US_State  \
# ResponseId
# 1                                                    Slovakia      NaN
# ...

# %%
df['ConvertedCompYearly'].head(15)
# Out:
# ResponseId
# 1     62268.0
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10    51552.0
# 11        NaN
# 12    46482.0
# 13    77290.0
# 14        NaN
# 15        NaN
# Name: ConvertedCompYearly, dtype: float64

# %%
df['ConvertedCompYearly'].tail(15)
# Out:
# ResponseId
# 83425     129718.0
# 83426      19452.0
# 83427          NaN
# 83428    4300000.0
# 83429      41232.0
# 83430          NaN
# 83431     125000.0
# 83432      11676.0
# 83433      80169.0
# 83434      18326.0
# 83435     160500.0
# 83436       3960.0
# 83437      90000.0
# 83438     816816.0
# 83439      21168.0
# Name: ConvertedCompYearly, dtype: float64

# %%
df['ConvertedCompYearly'].median()
# Out:
# 56211.0

# %%
df.median()
# Out:
# /var/folders/3s/g1lyd01905s33dt6txc6jyc00000gn/T/ipykernel_4847/530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# CompTotal              67000.0
# ConvertedCompYearly    56211.0
# dtype: float64

# %%
df.describe()
# Out:
#           CompTotal  ConvertedCompYearly
# count  4.718300e+04         4.684400e+04
# mean   2.119407e+69         1.184262e+05
# std    4.603702e+71         5.272944e+05
# min    0.000000e+00         1.000000e+00
# 25%    1.600000e+04         2.702500e+04
# 50%    6.700000e+04         5.621100e+04
# 75%    1.400000e+05         1.000000e+05
# max    1.000000e+74         4.524131e+07

# %%
df['ConvertedCompYearly'].count()
# Out:
# 46844

# %%
df['LanguageHaveWorkedWith']
# Out:
# ResponseId
# 1        C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 2                                    JavaScript;Python
# 3                             Assembly;C;Python;R;Rust
# 4                                JavaScript;TypeScript
# 5                       Bash/Shell;HTML/CSS;Python;SQL
#                              ...
# 83435                               Clojure;Kotlin;SQL
# 83436                                              NaN
# 83437                               Groovy;Java;Python
# 83438             Bash/Shell;JavaScript;Node.js;Python
# 83439           Delphi;Elixir;HTML/CSS;Java;JavaScript
# Name: LanguageHaveWorkedWith, Length: 83439, dtype: object

# %%
df['Gender']
# Out:
# ResponseId
# 1        Man
# 2        Man
# 3        Man
# 4        Man
# 5        Man
#         ...
# 83435    Man
# 83436    Man
# 83437    Man
# 83438    Man
# 83439    Man
# Name: Gender, Length: 83439, dtype: object

# %%
df['Gender'].count()
# Out:
# 82286

# %%
df['Gender'].value_counts()
# Out:
# Man                                                                                   74817
# Woman                                                                                  4120
# Prefer not to say                                                                      1442
# Non-binary, genderqueer, or gender non-conforming                                       690
# Or, in your own words:                                                                  413
# Man;Or, in your own words:                                                              268
# Man;Non-binary, genderqueer, or gender non-conforming                                   252
# Woman;Non-binary, genderqueer, or gender non-conforming                                 147
# Man;Woman                                                                                41
# Non-binary, genderqueer, or gender non-conforming;Or, in your own words:                 21
# ...

# %%
df['LanguageHaveWorkedWith'].value_counts()
# Out:
# Python                                                                                                 1337
# HTML/CSS;JavaScript;Node.js;TypeScript                                                                  811
# Java                                                                                                    715
# HTML/CSS;JavaScript;PHP;SQL                                                                             674
# C#                                                                                                      597
#                                                                                                        ...
# Assembly;Bash/Shell;C;C#;C++;Delphi;HTML/CSS;Java;JavaScript;Kotlin;Node.js;Perl;PHP;Python;SQL;VBA       1
# C#;C++;Dart;Go;JavaScript;Node.js;SQL;TypeScript                                                          1
# Bash/Shell;C;C++;Groovy;HTML/CSS;Java;JavaScript;Node.js;SQL;TypeScript                                   1
# ...

# %%
df['WebframeHaveWorkedWith']
# Out:
# ResponseId
# 1                                     Laravel;Symfony
# 2                                Angular;Flask;Vue.js
# 3                                               Flask
# 4                                      Angular;jQuery
# 5                                               Flask
#                              ...
# 83435                                             NaN
# 83436    Django;jQuery;Laravel;React.js;Ruby on Rails
# 83437                                   FastAPI;Flask
# 83438                   Django;Express;Flask;React.js
# 83439                                  Angular;Spring
# Name: WebframeHaveWorkedWith, Length: 83439, dtype: object

# %%
df['WebframeHaveWorkedWith'].value_counts()
# Out:
# React.js                                                                                                                                            3383
# jQuery                                                                                                                                              2358
# Express;React.js                                                                                                                                    1951
# Flask                                                                                                                                               1815
# Spring                                                                                                                                              1711
#                                                                                                                                                     ...
# ...

# %%
schema_df
# Out:
#                        qid                                           question  \
# qname
# S0                   QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo             QID12                                  Browser Meta Info
# S1                    QID1  <span style="font-size:22px; font-family: aria...
# MainBranch            QID2  Which of the following options best describes ...
# Employment           QID24  Which of the following best describes your cur...
# Country               QID6  Where do you live? <span style="font-weight: b...
# US_State              QID7  <p>In which state or territory of the USA do y...
# UK_Country            QID9  In which part of the United Kingdom do you liv...
# S2                  QID190  <span style="font-size:22px; font-family: aria...
# EdLevel              QID25  Which of the following best describes the high...
# Age1stCode          QID149  At what age did you write your first line of c...
# ...

# %%
schema_df.loc['Language']
# Out:
# qid                                                      QID233
# question      Which <b>programming, scripting, and markup la...
# force_resp                                                False
# type                                                     Matrix
# selector                                                 Likert
# Name: Language, dtype: object

# %%
df['LanguageHaveWorkedWith'].value_counts()
# Out:
# Python                                                                                                 1337
# HTML/CSS;JavaScript;Node.js;TypeScript                                                                  811
# Java                                                                                                    715
# HTML/CSS;JavaScript;PHP;SQL                                                                             674
# C#                                                                                                      597
#                                                                                                        ...
# Assembly;Bash/Shell;C;C#;C++;Delphi;HTML/CSS;Java;JavaScript;Kotlin;Node.js;Perl;PHP;Python;SQL;VBA       1
# C#;C++;Dart;Go;JavaScript;Node.js;SQL;TypeScript                                                          1
# Bash/Shell;C;C++;Groovy;HTML/CSS;Java;JavaScript;Node.js;SQL;TypeScript                                   1
# ...

# %%
df['LanguageHaveWorkedWith'].value_counts(normalize=True)
# Out:
# Python                                                                                                 0.016234
# HTML/CSS;JavaScript;Node.js;TypeScript                                                                 0.009847
# Java                                                                                                   0.008682
# HTML/CSS;JavaScript;PHP;SQL                                                                            0.008184
# C#                                                                                                     0.007249
#                                                                                                          ...
# Assembly;Bash/Shell;C;C#;C++;Delphi;HTML/CSS;Java;JavaScript;Kotlin;Node.js;Perl;PHP;Python;SQL;VBA    0.000012
# C#;C++;Dart;Go;JavaScript;Node.js;SQL;TypeScript                                                       0.000012
# ...

# %%
df['Gender'].value_counts(normalize=True)
# Out:
# Man                                                                                   0.909231
# Woman                                                                                 0.050069
# Prefer not to say                                                                     0.017524
# Non-binary, genderqueer, or gender non-conforming                                     0.008385
# Or, in your own words:                                                                0.005019
# Man;Or, in your own words:                                                            0.003257
# Man;Non-binary, genderqueer, or gender non-conforming                                 0.003062
# Woman;Non-binary, genderqueer, or gender non-conforming                               0.001786
# Man;Woman                                                                             0.000498
# Non-binary, genderqueer, or gender non-conforming;Or, in your own words:              0.000255
# ...

# %%
df['Gender'].value_counts()
# Out:
# Man                                                                                   74817
# Woman                                                                                  4120
# Prefer not to say                                                                      1442
# Non-binary, genderqueer, or gender non-conforming                                       690
# Or, in your own words:                                                                  413
# Man;Or, in your own words:                                                              268
# Man;Non-binary, genderqueer, or gender non-conforming                                   252
# Woman;Non-binary, genderqueer, or gender non-conforming                                 147
# Man;Woman                                                                                41
# Non-binary, genderqueer, or gender non-conforming;Or, in your own words:                 21
# ...

# %%
df['Country'].value_counts()
# Out:
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
#                                                         ...
# Saint Kitts and Nevis                                       1
# Dominica                                                    1
# Saint Vincent and the Grenadines                            1
# Tuvalu                                                      1
# Papua New Guinea                                            1
# Name: Country, Length: 181, dtype: int64

# %%
df.groupby(['Country'])

# %%
country_groupby = df.groupby(['Country'])

# %%
country_groupby.get_group('United States of America')
# Out:
#                                         MainBranch  \
# ResponseId
# 6           I am a student who is learning to code
# 7                      I code primarily as a hobby
# 16          I am a student who is learning to code
# 37                  I am a developer by profession
# 38                  I am a developer by profession
# ...                                            ...
# 83428               I am a developer by profession
# 83430                  I code primarily as a hobby
# 83431               I am a developer by profession
# 83435               I am a developer by profession
# 83437               I am a developer by profession
#
#                                     Employment                   Country  \
# ResponseId
# 6                           Student, part-time  United States of America
# 7                          I prefer not to say  United States of America
# 16                          Student, full-time  United States of America
# ...

# %%
filt = df['Country'] == 'United States of America'

# %%
df.loc[filt]
# Out:
#                                         MainBranch  \
# ResponseId
# 6           I am a student who is learning to code
# 7                      I code primarily as a hobby
# 16          I am a student who is learning to code
# 37                  I am a developer by profession
# 38                  I am a developer by profession
# ...                                            ...
# 83428               I am a developer by profession
# 83430                  I code primarily as a hobby
# 83431               I am a developer by profession
# 83435               I am a developer by profession
# 83437               I am a developer by profession
#
#                                     Employment                   Country  \
# ResponseId
# 6                           Student, part-time  United States of America
# 7                          I prefer not to say  United States of America
# 16                          Student, full-time  United States of America
# ...

# %%
filt = df['Country'] == 'India'

# %%
df.loc[filt]['Gender'].value_counts()
# Out:
# Man                                                            9427
# Woman                                                           581
# Prefer not to say                                               197
# Or, in your own words:                                           24
# Man;Or, in your own words:                                       17
# Non-binary, genderqueer, or gender non-conforming                13
# Man;Woman                                                         9
# Man;Non-binary, genderqueer, or gender non-conforming             6
# Man;Woman;Non-binary, genderqueer, or gender non-conforming       1
# Woman;Or, in your own words:                                      1
# Woman;Non-binary, genderqueer, or gender non-conforming           1
# Name: Gender, dtype: int64

# %%
country_groupby['Gender'].value_counts()
# Out:
# Country      Gender
# Afghanistan  Man                                                  36
#              Non-binary, genderqueer, or gender non-conforming     5
#              Or, in your own words:                                5
#              Woman                                                 4
#              Prefer not to say                                     3
#                                                                   ..
# Zambia       Man;Or, in your own words:                            1
#              Prefer not to say                                     1
# Zimbabwe     Man                                                  33
#              Woman                                                 2
#              Or, in your own words:                                1
# Name: Gender, Length: 789, dtype: int64

# %%
country_groupby['Gender'].value_counts().head(50)
# Out:
# Country      Gender
# Afghanistan  Man                                                                                     36
#              Non-binary, genderqueer, or gender non-conforming                                        5
#              Or, in your own words:                                                                   5
#              Woman                                                                                    4
#              Prefer not to say                                                                        3
#              Man;Non-binary, genderqueer, or gender non-conforming                                    1
#              Man;Woman;Non-binary, genderqueer, or gender non-conforming;Or, in your own words:       1
# Albania      Man                                                                                     55
#              Woman                                                                                    8
# ...

# %%
country_groupby['Gender'].value_counts().loc['Albania']
# Out:
# Gender
# Man                                                                         55
# Woman                                                                        8
# Prefer not to say                                                            5
# Man;Woman;Non-binary, genderqueer, or gender non-conforming                  1
# Non-binary, genderqueer, or gender non-conforming;Or, in your own words:     1
# Name: Gender, dtype: int64

# %%
country_groupby['Gender'].value_counts().loc['United States of America']
# Out:
# Gender
# Man                                                                                   13185
# Woman                                                                                   908
# Prefer not to say                                                                       346
# Non-binary, genderqueer, or gender non-conforming                                       217
# Or, in your own words:                                                                   92
# Man;Non-binary, genderqueer, or gender non-conforming                                    89
# Woman;Non-binary, genderqueer, or gender non-conforming                                  65
# Man;Or, in your own words:                                                               50
# Non-binary, genderqueer, or gender non-conforming;Or, in your own words:                  7
# Woman;Or, in your own words:                                                              7
# ...

# %%
country_groupby['ConvertedCompYearly'].median()
# Out:
# Country
# Afghanistan                              9792.0
# Albania                                 15900.0
# Algeria                                  9875.0
# Andorra                                 94045.5
# Angola                                   9750.0
#                                          ...
# Venezuela, Bolivarian Republic of...    12000.0
# Viet Nam                                12678.0
# Yemen                                    3954.0
# Zambia                                   9816.0
# Zimbabwe                                 7200.0
# Name: ConvertedCompYearly, Length: 181, dtype: float64

# %%
country_groupby['ConvertedCompYearly'].median().loc['Albania']
# Out:
# 15900.0

# %%
country_groupby['ConvertedCompYearly'].agg(['median', 'min']).loc['Albania']
# Out:
# median    15900.0
# min          48.0
# Name: Albania, dtype: float64

# %%
country_groupby['ConvertedCompYearly'].agg(['median', 'min', 'max']).loc['Albania']
# Out:
# median     15900.0
# min           48.0
# max       692042.0
# Name: Albania, dtype: float64

# %%
filt=df['Country'] == 'Albania'
df.loc[filt]['LanguageHaveWorkedWith']
# Out:
# ResponseId
# 118                            HTML/CSS;JavaScript;Node.js
# 1924                                         C#;JavaScript
# 3358                                   HTML/CSS;JavaScript
# 6335     C#;Dart;Groovy;JavaScript;Julia;Matlab;PowerSh...
# 6764                                   HTML/CSS;JavaScript
#                                ...
# 79919                                                  NaN
# 80416                         C#;JavaScript;SQL;TypeScript
# 81064                                   C#;Java;TypeScript
# 81674                               C#;HTML/CSS;JavaScript
# 82700    HTML/CSS;Java;JavaScript;Node.js;PHP;Python;SQ...
# Name: LanguageHaveWorkedWith, Length: 73, dtype: object

# %%
filt=df['Country'] == 'Albania'
df.loc[filt]['LanguageHaveWorkedWith'].str.contains('JavaScript')
# Out:
# ResponseId
# 118       True
# 1924      True
# 3358      True
# 6335      True
# 6764      True
#          ...
# 79919      NaN
# 80416     True
# 81064    False
# 81674     True
# 82700     True
# Name: LanguageHaveWorkedWith, Length: 73, dtype: object

# %%
country_groupby['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('JavaScript').sum())
# Out:
# Country
# Afghanistan                              32
# Albania                                  51
# Algeria                                  29
# Andorra                                   8
# Angola                                   14
#                                        ...
# Venezuela, Bolivarian Republic of...     91
# Viet Nam                                244
# Yemen                                     8
# Zambia                                   16
# Zimbabwe                                 22
# Name: LanguageHaveWorkedWith, Length: 181, dtype: int64
