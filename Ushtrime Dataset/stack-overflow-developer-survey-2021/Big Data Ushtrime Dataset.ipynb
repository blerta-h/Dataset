# %%
import pandas as pd
df=pd.read_csv('survey_results_public.csv')
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Student, full-time
# 2                                     Student, full-time
# 3                                     Employed full-time
# 4      Independent contractor, freelancer, or self-em...
# ...                                                  ...
# 83434                                 Employed full-time
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
# 83438                                 Employed full-time
#
#                                                  Country    US_State  \
# 0                                               Slovakia         NaN
# 1                                            Netherlands         NaN
# 2                                     Russian Federation         NaN
# 3                                                Austria         NaN
# 4      United Kingdom of Great Britain and Northern I...         NaN
# ...                                                  ...         ...
# 83434                           United States of America       Texas
# 83435                                              Benin         NaN
# 83436                           United States of America  New Jersey
# 83437                                             Canada         NaN
# 83438                                             Brazil         NaN
#
#       UK_Country                                            EdLevel  \
# 0            NaN  Secondary school (e.g. American high school, G...
# 1            NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2            NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3            NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4        England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...          ...                                                ...
# 83434        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83435        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83436        NaN  Secondary school (e.g. American high school, G...
# 83437        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83438        NaN                 Professional degree (JD, MD, etc.)
#
#           Age1stCode                                          LearnCode  \
# 0      18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 1      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 2      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3      11 - 17 years                                                NaN
# 4       5 - 10 years                            Friend or family member
# ...              ...                                                ...
# 83434  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83435  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83436  11 - 17 years                                             School
# 83437  11 - 17 years  Online Courses or Certification;Books / Physic...
# 83438  11 - 17 years                                             School
#
#       YearsCode  ...              Age Gender Trans                Sexuality  \
# 0           NaN  ...  25-34 years old    Man    No  Straight / Heterosexual
# 1             7  ...  18-24 years old    Man    No  Straight / Heterosexual
# 2           NaN  ...  18-24 years old    Man    No        Prefer not to say
# 3           NaN  ...  35-44 years old    Man    No  Straight / Heterosexual
# 4            17  ...  25-34 years old    Man    No                      NaN
# ...         ...  ...              ...    ...   ...                      ...
# 83434         6  ...  25-34 years old    Man    No  Straight / Heterosexual
# 83435         4  ...  18-24 years old    Man    No  Straight / Heterosexual
# 83436        10  ...  25-34 years old    Man    No                      NaN
# 83437         5  ...  25-34 years old    Man    No  Straight / Heterosexual
# 83438        14  ...  18-24 years old    Man    No  Straight / Heterosexual
#
#                           Ethnicity                Accessibility  \
# 0      White or of European descent            None of the above
# 1      White or of European descent            None of the above
# 2                 Prefer not to say            None of the above
# 3      White or of European descent  I am deaf / hard of hearing
# 4      White or of European descent            None of the above
# ...                             ...                          ...
# 83434  White or of European descent            None of the above
# 83435   Black or of African descent            None of the above
# 83436  White or of European descent            None of the above
# 83437  White or of European descent            None of the above
# 83438        Hispanic or Latino/a/x            None of the above
#
#                                             MentalHealth  \
# 0                                      None of the above
# 1                                      None of the above
# 2                                      None of the above
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 83434  I have a concentration and/or memory disorder ...
# 83435                                  None of the above
# 83436                                  None of the above
# 83437  I have a mood or emotional disorder (e.g. depr...
# 83438                                  None of the above
#
#                 SurveyLength                  SurveyEase ConvertedCompYearly
# 0      Appropriate in length                        Easy             62268.0
# 1      Appropriate in length                        Easy                 NaN
# 2      Appropriate in length                        Easy                 NaN
# 3      Appropriate in length  Neither easy nor difficult                 NaN
# 4      Appropriate in length                        Easy                 NaN
# ...                      ...                         ...                 ...
# 83434  Appropriate in length                        Easy            160500.0
# 83435  Appropriate in length                        Easy              3960.0
# 83436  Appropriate in length  Neither easy nor difficult             90000.0
# 83437  Appropriate in length  Neither easy nor difficult            816816.0
# 83438  Appropriate in length                        Easy             21168.0
#
# [83439 rows x 48 columns]

# %%
df.shape
# Out:
# (83439, 48)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83439 entries, 0 to 83438
# Data columns (total 48 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ResponseId                    83439 non-null  int64
#  1   MainBranch                    83439 non-null  object
#  2   Employment                    83323 non-null  object
#  3   Country                       83439 non-null  object
#  4   US_State                      14920 non-null  object
#  5   UK_Country                    4418 non-null   object
#  6   EdLevel                       83126 non-null  object
#  7   Age1stCode                    83243 non-null  object
#  8   LearnCode                     82963 non-null  object
#  9   YearsCode                     81641 non-null  object
#  10  YearsCodePro                  61216 non-null  object
#  11  DevType                       66484 non-null  object
#  12  OrgSize                       60726 non-null  object
#  13  Currency                      61080 non-null  object
#  14  CompTotal                     47183 non-null  float64
#  15  CompFreq                      52150 non-null  object
#  16  LanguageHaveWorkedWith        82357 non-null  object
#  17  LanguageWantToWorkWith        76821 non-null  object
#  18  DatabaseHaveWorkedWith        69546 non-null  object
#  19  DatabaseWantToWorkWith        58299 non-null  object
#  20  PlatformHaveWorkedWith        52135 non-null  object
#  21  PlatformWantToWorkWith        41619 non-null  object
#  22  WebframeHaveWorkedWith        61707 non-null  object
#  23  WebframeWantToWorkWith        52095 non-null  object
#  24  MiscTechHaveWorkedWith        47055 non-null  object
#  25  MiscTechWantToWorkWith        38021 non-null  object
#  26  ToolsTechHaveWorkedWith       72537 non-null  object
#  27  ToolsTechWantToWorkWith       65480 non-null  object
#  28  NEWCollabToolsHaveWorkedWith  81234 non-null  object
#  29  NEWCollabToolsWantToWorkWith  73022 non-null  object
#  30  OpSys                         83294 non-null  object
#  31  NEWStuck                      83052 non-null  object
#  32  NEWSOSites                    83171 non-null  object
#  33  SOVisitFreq                   82413 non-null  object
#  34  SOAccount                     82525 non-null  object
#  35  SOPartFreq                    67553 non-null  object
#  36  SOComm                        82319 non-null  object
#  37  NEWOtherComms                 82828 non-null  object
#  38  Age                           82407 non-null  object
#  39  Gender                        82286 non-null  object
#  40  Trans                         80678 non-null  object
#  41  Sexuality                     73366 non-null  object
#  42  Ethnicity                     79464 non-null  object
#  43  Accessibility                 77603 non-null  object
#  44  MentalHealth                  76920 non-null  object
#  45  SurveyLength                  81711 non-null  object
#  46  SurveyEase                    81948 non-null  object
#  47  ConvertedCompYearly           46844 non-null  float64
# dtypes: float64(2), int64(1), object(45)
# memory usage: 30.6+ MB

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %%
schema_df=pd.read_csv('survey_results_schema.csv')
schema_df
# Out:
#        qid               qname  \
# 0    QID16                  S0
# 1    QID12            MetaInfo
# 2     QID1                  S1
# 3     QID2          MainBranch
# 4    QID24          Employment
# 5     QID6             Country
# 6     QID7            US_State
# 7     QID9          UK_Country
# 8   QID190                  S2
# 9    QID25             EdLevel
# 10  QID149          Age1stCode
# 11  QID276           LearnCode
# 12   QID32           YearsCode
# 13   QID34        YearsCodePro
# 14   QID31             DevType
# 15   QID29             OrgSize
# 16   QID50            Currency
# 17   QID51           CompTotal
# 18   QID52            CompFreq
# 19   QID61                  S3
# 20  QID233            Language
# 21  QID262            Database
# 22  QID263            Platform
# 23  QID264            Webframe
# 24  QID265            MiscTech
# 25  QID275           ToolsTech
# 26  QID274      NEWCollabTools
# 27   QID71               OpSys
# 28  QID243            NEWStuck
# 29   QID91                  S4
# 30  QID266          NEWSOSites
# 31  QID100         SOVisitFreq
# 32  QID101           SOAccount
# 33  QID102          SOPartFreq
# 34  QID106              SOComm
# 35  QID267       NEWOtherComms
# 36  QID268  NEWOtherCommsNames
# 37  QID121                  S5
# 38  QID127                 Age
# 39  QID122              Gender
# 40  QID153               Trans
# 41  QID136           Sexuality
# 42  QID126           Ethnicity
# 43  QID124       Accessibility
# 44  QID125        MentalHealth
# 45  QID131                  S6
# 46  QID132        SurveyLength
# 47  QID133          SurveyEase
#
#                                              question  force_resp    type  \
# 0   <div><span style="font-size:19px;"><strong>Hel...       False      DB
# 1                                   Browser Meta Info       False    Meta
# 2   <span style="font-size:22px; font-family: aria...       False      DB
# 3   Which of the following options best describes ...        True      MC
# 4   Which of the following best describes your cur...       False      MC
# 5   Where do you live? <span style="font-weight: b...        True      MC
# 6   <p>In which state or territory of the USA do y...       False      MC
# 7   In which part of the United Kingdom do you liv...       False      MC
# 8   <span style="font-size:22px; font-family: aria...       False      DB
# 9   Which of the following best describes the high...       False      MC
# 10  At what age did you write your first line of c...       False      MC
# 11  How did you learn to code? Select all that apply.       False      MC
# 12  Including any education, how many years have y...       False      MC
# 13  NOT including education, how many years have y...       False      MC
# 14  Which of the following describes your current ...       False      MC
# 15  Approximately how many people are employed by ...       False      MC
# 16  Which currency do you use day-to-day? If your ...        True      MC
# 17  What is your current total compensation (salar...       False      TE
# 18   Is that compensation weekly, monthly, or yearly?       False      MC
# 19  <span style="font-size:22px; font-family: aria...       False      DB
# 20  Which <b>programming, scripting, and markup la...       False  Matrix
# 21  Which <b>database environments </b>have you do...       False  Matrix
# 22  Which <b>cloud platforms</b> have you done ext...       False  Matrix
# 23  Which <strong>web frameworks </strong><span st...       False  Matrix
# 24  Which <b>other frameworks and libraries</b> ha...       False  Matrix
# 25  Which <strong>tools</strong> have you done ext...       False  Matrix
# 26  Which <strong>development environments</strong...       False  Matrix
# 27  What is the primary operating system in which ...       False      MC
# 28  What do you do when you get stuck on a problem...       False      MC
# 29  <span style="font-size:22px; font-family: aria...       False      DB
# 30  Which of the following Stack Overflow sites ha...       False      MC
# 31  How frequently would you say you visit Stack O...       False      MC
# 32              Do you have a Stack Overflow account?       False      MC
# 33  How frequently would you say you participate i...       False      MC
# 34  Do you consider yourself a member of the Stack...       False      MC
# 35  Are you a member of any other online developer...       False      MC
# 36  Please name up to 5 other online developer com...       False  Matrix
# 37  <span style="font-size:22px; font-family: aria...       False      DB
# 38                                  What is your age?       False      MC
# 39  Which of the following describe you, if any? P...       False      MC
# 40                    Do you identify as transgender?       False      MC
# 41  Which of the following describe you, if any? P...       False      MC
# 42  Which of the following describe you, if any? P...       False      MC
# 43  Which of the following describe you, if any? P...       False      MC
# 44  Which of the following describe you, if any? P...       False      MC
# 45  <span style="font-size:22px;"><strong>Final Qu...       False      DB
# 46  How do you feel about the length of the survey...       False      MC
# 47  How easy or difficult was this survey to compl...       False      MC
#
#    selector
# 0        TB
# 1   Browser
# 2        TB
# 3      SAVR
# 4      MAVR
# 5        DL
# 6        DL
# 7        DL
# 8        TB
# 9      SAVR
# 10     MAVR
# 11     MAVR
# 12       DL
# 13       DL
# 14     MAVR
# 15     MAVR
# 16       SB
# 17       SL
# 18     MAVR
# 19       TB
# 20   Likert
# 21   Likert
# 22   Likert
# 23   Likert
# 24   Likert
# 25   Likert
# 26   Likert
# 27     SAVR
# 28     MAVR
# 29       TB
# 30     MAVR
# 31     MAVR
# 32     MAVR
# 33     MAVR
# 34     MAVR
# 35     MAVR
# 36   Likert
# 37       TB
# 38     MAVR
# 39     MAVR
# 40     MAVR
# 41     MAVR
# 42     MAVR
# 43     MAVR
# 44     MAVR
# 45       TB
# 46     MAVR
# 47     MAVR

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Student, full-time
# 2                                     Student, full-time
# 3                                     Employed full-time
# 4      Independent contractor, freelancer, or self-em...
# ...                                                  ...
# 83434                                 Employed full-time
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
# 83438                                 Employed full-time
#
#                                                  Country    US_State  \
# 0                                               Slovakia         NaN
# 1                                            Netherlands         NaN
# 2                                     Russian Federation         NaN
# 3                                                Austria         NaN
# 4      United Kingdom of Great Britain and Northern I...         NaN
# ...                                                  ...         ...
# 83434                           United States of America       Texas
# 83435                                              Benin         NaN
# 83436                           United States of America  New Jersey
# 83437                                             Canada         NaN
# 83438                                             Brazil         NaN
#
#       UK_Country                                            EdLevel  \
# 0            NaN  Secondary school (e.g. American high school, G...
# 1            NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2            NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3            NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4        England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...          ...                                                ...
# 83434        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83435        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83436        NaN  Secondary school (e.g. American high school, G...
# 83437        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83438        NaN                 Professional degree (JD, MD, etc.)
#
#           Age1stCode                                          LearnCode  \
# 0      18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 1      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 2      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3      11 - 17 years                                                NaN
# 4       5 - 10 years                            Friend or family member
# ...              ...                                                ...
# 83434  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83435  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83436  11 - 17 years                                             School
# 83437  11 - 17 years  Online Courses or Certification;Books / Physic...
# 83438  11 - 17 years                                             School
#
#       YearsCode YearsCodePro  \
# 0           NaN          NaN
# 1             7          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4            17           10
# ...         ...          ...
# 83434         6            5
# 83435         4            2
# 83436        10            4
# 83437         5            3
# 83438        14            4
#
#                                                  DevType  \
# 0                                      Developer, mobile
# 1                                                    NaN
# 2                                                    NaN
# 3                                   Developer, front-end
# 4      Developer, desktop or enterprise applications;...
# ...                                                  ...
# 83434                                Developer, back-end
# 83435                              Developer, full-stack
# 83436  Data scientist or machine learning specialist;...
# 83437                                Developer, back-end
# 83438  Developer, front-end;Developer, full-stack;Dev...
#
#                                                  OrgSize  \
# 0                                     20 to 99 employees
# 1                                                    NaN
# 2                                                    NaN
# 3                                   100 to 499 employees
# 4      Just me - I am a freelancer, sole proprietor, ...
# ...                                                  ...
# 83434                                 20 to 99 employees
# 83435  Just me - I am a freelancer, sole proprietor, ...
# 83436                           10,000 or more employees
# 83437                                 20 to 99 employees
# 83438                                       I don’t know
#
#                           Currency  CompTotal CompFreq  \
# 0                EUR European Euro     4800.0  Monthly
# 1                              NaN        NaN      NaN
# 2                              NaN        NaN      NaN
# 3                EUR European Euro        NaN  Monthly
# 4              GBP\tPound sterling        NaN      NaN
# ...                            ...        ...      ...
# 83434    USD\tUnited States dollar   160500.0   Yearly
# 83435  XOF\tWest African CFA franc   200000.0  Monthly
# 83436    USD\tUnited States dollar     1800.0   Weekly
# 83437         CAD\tCanadian dollar    90000.0  Monthly
# 83438          BRL\tBrazilian real     7700.0  Monthly
#
#                               LanguageHaveWorkedWith  \
# 0      C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1                                  JavaScript;Python
# 2                           Assembly;C;Python;R;Rust
# 3                              JavaScript;TypeScript
# 4                     Bash/Shell;HTML/CSS;Python;SQL
# ...                                              ...
# 83434                             Clojure;Kotlin;SQL
# 83435                                            NaN
# 83436                             Groovy;Java;Python
# 83437           Bash/Shell;JavaScript;Node.js;Python
# 83438         Delphi;Elixir;HTML/CSS;Java;JavaScript
#
#                                   LanguageWantToWorkWith  \
# 0                                                  Swift
# 1                                                    NaN
# 2                                      Julia;Python;Rust
# 3                                  JavaScript;TypeScript
# 4                         Bash/Shell;HTML/CSS;Python;SQL
# ...                                                  ...
# 83434                                            Clojure
# 83435                                                NaN
# 83436                                        Java;Python
# 83437                                            Go;Rust
# 83438  Elixir;HTML/CSS;Java;JavaScript;Node.js;PHP;SQ...
#
#                                  DatabaseHaveWorkedWith  \
# 0                                     PostgreSQL;SQLite
# 1                                            PostgreSQL
# 2                                                SQLite
# 3                                                   NaN
# 4                        Elasticsearch;PostgreSQL;Redis
# ...                                                 ...
# 83434                                     Oracle;SQLite
# 83435    Firebase;MariaDB;MySQL;PostgreSQL;Redis;SQLite
# 83436   DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83437  Cassandra;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83438                                 Oracle;PostgreSQL
#
#                                   DatabaseWantToWorkWith  \
# 0                                                 SQLite
# 1                                                    NaN
# 2                                                 SQLite
# 3                                                    NaN
# 4               Cassandra;Elasticsearch;PostgreSQL;Redis
# ...                                                  ...
# 83434                                             SQLite
# 83435  Firebase;MariaDB;MongoDB;MySQL;PostgreSQL;Redi...
# 83436                                     DynamoDB;Redis
# 83437                                                NaN
# 83438  Elasticsearch;MongoDB;MySQL;Oracle;PostgreSQL;...
#
#           PlatformHaveWorkedWith PlatformWantToWorkWith  \
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2                         Heroku                    NaN
# 3                            NaN                    NaN
# 4                            NaN                    NaN
# ...                          ...                    ...
# 83434                        AWS                    AWS
# 83435                        NaN                    NaN
# 83436  AWS;Google Cloud Platform                    AWS
# 83437                     Heroku       AWS;DigitalOcean
# 83438            Microsoft Azure                    AWS
#
#                              WebframeHaveWorkedWith  \
# 0                                   Laravel;Symfony
# 1                              Angular;Flask;Vue.js
# 2                                             Flask
# 3                                    Angular;jQuery
# 4                                             Flask
# ...                                             ...
# 83434                                           NaN
# 83435  Django;jQuery;Laravel;React.js;Ruby on Rails
# 83436                                 FastAPI;Flask
# 83437                 Django;Express;Flask;React.js
# 83438                                Angular;Spring
#
#                                   WebframeWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                  Flask
# 3                                         Angular;jQuery
# 4                                                  Flask
# ...                                                  ...
# 83434                                                NaN
# 83435  Django;Express;jQuery;Laravel;React.js;Ruby on...
# 83436                                      FastAPI;Flask
# 83437                                                NaN
# 83438                     Express;Laravel;Spring;Symfony
#
#                       MiscTechHaveWorkedWith  \
# 0                                        NaN
# 1                                    Cordova
# 2      NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                        NaN
# 4           Apache Spark;Hadoop;NumPy;Pandas
# ...                                      ...
# 83434                                    NaN
# 83435                             Flutter;Qt
# 83436              Hadoop;Keras;NumPy;Pandas
# 83437  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                    NaN
#
#                                   MiscTechWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2            Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                                    NaN
# 4                                    Hadoop;NumPy;Pandas
# ...                                                  ...
# 83434                                                NaN
# 83435                                                NaN
# 83436  Apache Spark;Hadoop;Keras;NumPy;Pandas;TensorFlow
# 83437              NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                                NaN
#
#             ToolsTechHaveWorkedWith          ToolsTechWantToWorkWith  \
# 0                               NaN                              NaN
# 1                   Docker;Git;Yarn                              Git
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4        Docker;Git;Kubernetes;Yarn       Docker;Git;Kubernetes;Yarn
# ...                             ...                              ...
# 83434                    Docker;Git                   Git;Kubernetes
# 83435    Git;Unity 3D;Unreal Engine            Docker;Git;Kubernetes
# 83436  Ansible;Docker;Git;Terraform  Docker;Git;Kubernetes;Terraform
# 83437  Ansible;Docker;Git;Terraform             Kubernetes;Terraform
# 83438                    Docker;Git            Docker;Git;Kubernetes
#
#                             NEWCollabToolsHaveWorkedWith  \
# 0                                         PHPStorm;Xcode
# 1              Android Studio;IntelliJ;Notepad++;PyCharm
# 2      IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 3                                                    NaN
# 4             Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
# ...                                                  ...
# 83434       IntelliJ;Sublime Text;Vim;Visual Studio Code
# 83435  Android Studio;Eclipse;Emacs;IntelliJ;NetBeans...
# 83436  Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
# 83437                               PyCharm;Sublime Text
# 83438                        IntelliJ;Visual Studio Code
#
#                             NEWCollabToolsWantToWorkWith        OpSys  \
# 0                                             Atom;Xcode        MacOS
# 1                                                    NaN      Windows
# 2      IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 3                                                    NaN      Windows
# 4      Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
# ...                                                  ...          ...
# 83434                                   Sublime Text;Vim        MacOS
# 83435  Emacs;IntelliJ;PHPStorm;PyCharm;RStudio;Sublim...  Linux-based
# 83436             IntelliJ;IPython/Jupyter;Notepad++;Vim      Windows
# 83437                                                NaN        MacOS
# 83438               IntelliJ;PHPStorm;Visual Studio Code  Linux-based
#
#                                                 NEWStuck  \
# 0      Call a coworker or friend;Visit Stack Overflow...
# 1                         Visit Stack Overflow;Google it
# 2      Visit Stack Overflow;Google it;Watch help / tu...
# 3      Call a coworker or friend;Visit Stack Overflow...
# 4      Visit Stack Overflow;Go for a walk or other ph...
# ...                                                  ...
# 83434                Call a coworker or friend;Google it
# 83435  Call a coworker or friend;Visit Stack Overflow...
# 83436  Call a coworker or friend;Visit Stack Overflow...
# 83437  Call a coworker or friend;Visit Stack Overflow...
# 83438  Call a coworker or friend;Visit Stack Overflow...
#
#                                               NEWSOSites  \
# 0                                         Stack Overflow
# 1                                         Stack Overflow
# 2                          Stack Overflow;Stack Exchange
# 3                                         Stack Overflow
# 4                          Stack Overflow;Stack Exchange
# ...                                                  ...
# 83434                      Stack Overflow;Stack Exchange
# 83435                      Stack Overflow;Stack Exchange
# 83436                      Stack Overflow;Stack Exchange
# 83437                                     Stack Overflow
# 83438  Stack Overflow;Stack Exchange;Stack Overflow f...
#
#                            SOVisitFreq SOAccount  \
# 0               Multiple times per day       Yes
# 1                Daily or almost daily       Yes
# 2               Multiple times per day       Yes
# 3                Daily or almost daily       Yes
# 4                Daily or almost daily       Yes
# ...                                ...       ...
# 83434             A few times per week        No
# 83435           Multiple times per day       Yes
# 83436             A few times per week       Yes
# 83437  A few times per month or weekly       Yes
# 83438             A few times per week       Yes
#
#                                               SOPartFreq           SOComm  \
# 0                        A few times per month or weekly  Yes, definitely
# 1                                  Daily or almost daily  Yes, definitely
# 2                                 Multiple times per day  Yes, definitely
# 3                                  Daily or almost daily          Neutral
# 4                                   A few times per week    Yes, somewhat
# ...                                                  ...              ...
# 83434                                                NaN   No, not at all
# 83435  I have never participated in Q&A on Stack Over...    Yes, somewhat
# 83436  I have never participated in Q&A on Stack Over...   No, not really
# 83437                Less than once per month or monthly   No, not really
# 83438                               A few times per week    Yes, somewhat
#
#       NEWOtherComms              Age Gender Trans                Sexuality  \
# 0                No  25-34 years old    Man    No  Straight / Heterosexual
# 1                No  18-24 years old    Man    No  Straight / Heterosexual
# 2               Yes  18-24 years old    Man    No        Prefer not to say
# 3                No  35-44 years old    Man    No  Straight / Heterosexual
# 4                No  25-34 years old    Man    No                      NaN
# ...             ...              ...    ...   ...                      ...
# 83434            No  25-34 years old    Man    No  Straight / Heterosexual
# 83435            No  18-24 years old    Man    No  Straight / Heterosexual
# 83436            No  25-34 years old    Man    No                      NaN
# 83437            No  25-34 years old    Man    No  Straight / Heterosexual
# 83438            No  18-24 years old    Man    No  Straight / Heterosexual
#
#                           Ethnicity                Accessibility  \
# 0      White or of European descent            None of the above
# 1      White or of European descent            None of the above
# 2                 Prefer not to say            None of the above
# 3      White or of European descent  I am deaf / hard of hearing
# 4      White or of European descent            None of the above
# ...                             ...                          ...
# 83434  White or of European descent            None of the above
# 83435   Black or of African descent            None of the above
# 83436  White or of European descent            None of the above
# 83437  White or of European descent            None of the above
# 83438        Hispanic or Latino/a/x            None of the above
#
#                                             MentalHealth  \
# 0                                      None of the above
# 1                                      None of the above
# 2                                      None of the above
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 83434  I have a concentration and/or memory disorder ...
# 83435                                  None of the above
# 83436                                  None of the above
# 83437  I have a mood or emotional disorder (e.g. depr...
# 83438                                  None of the above
#
#                 SurveyLength                  SurveyEase  ConvertedCompYearly
# 0      Appropriate in length                        Easy              62268.0
# 1      Appropriate in length                        Easy                  NaN
# 2      Appropriate in length                        Easy                  NaN
# 3      Appropriate in length  Neither easy nor difficult                  NaN
# 4      Appropriate in length                        Easy                  NaN
# ...                      ...                         ...                  ...
# 83434  Appropriate in length                        Easy             160500.0
# 83435  Appropriate in length                        Easy               3960.0
# 83436  Appropriate in length  Neither easy nor difficult              90000.0
# 83437  Appropriate in length  Neither easy nor difficult             816816.0
# 83438  Appropriate in length                        Easy              21168.0
#
# [83439 rows x 48 columns]

# %%
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# 2                                 Russian Federation      NaN        NaN
# 3                                            Austria      NaN        NaN
# 4  United Kingdom of Great Britain and Northern I...      NaN    England
#
#                                              EdLevel     Age1stCode  \
# 0  Secondary school (e.g. American high school, G...  18 - 24 years
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 2       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 3    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  11 - 17 years
# 4    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)   5 - 10 years
#
#                                            LearnCode YearsCode YearsCodePro  \
# 0  Coding Bootcamp;Other online resources (ex: vi...       NaN          NaN
# 1  Other online resources (ex: videos, blogs, etc...         7          NaN
# 2  Other online resources (ex: videos, blogs, etc...       NaN          NaN
# 3                                                NaN       NaN          NaN
# 4                            Friend or family member        17           10
#
#                                              DevType  \
# 0                                  Developer, mobile
# 1                                                NaN
# 2                                                NaN
# 3                               Developer, front-end
# 4  Developer, desktop or enterprise applications;...
#
#                                              OrgSize             Currency  \
# 0                                 20 to 99 employees    EUR European Euro
# 1                                                NaN                  NaN
# 2                                                NaN                  NaN
# 3                               100 to 499 employees    EUR European Euro
# 4  Just me - I am a freelancer, sole proprietor, ...  GBP\tPound sterling
#
#    CompTotal CompFreq                         LanguageHaveWorkedWith  \
# 0     4800.0  Monthly  C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1        NaN      NaN                              JavaScript;Python
# 2        NaN      NaN                       Assembly;C;Python;R;Rust
# 3        NaN  Monthly                          JavaScript;TypeScript
# 4        NaN      NaN                 Bash/Shell;HTML/CSS;Python;SQL
#
#            LanguageWantToWorkWith          DatabaseHaveWorkedWith  \
# 0                           Swift               PostgreSQL;SQLite
# 1                             NaN                      PostgreSQL
# 2               Julia;Python;Rust                          SQLite
# 3           JavaScript;TypeScript                             NaN
# 4  Bash/Shell;HTML/CSS;Python;SQL  Elasticsearch;PostgreSQL;Redis
#
#                      DatabaseWantToWorkWith PlatformHaveWorkedWith  \
# 0                                    SQLite                    NaN
# 1                                       NaN                    NaN
# 2                                    SQLite                 Heroku
# 3                                       NaN                    NaN
# 4  Cassandra;Elasticsearch;PostgreSQL;Redis                    NaN
#
#   PlatformWantToWorkWith WebframeHaveWorkedWith WebframeWantToWorkWith  \
# 0                    NaN        Laravel;Symfony                    NaN
# 1                    NaN   Angular;Flask;Vue.js                    NaN
# 2                    NaN                  Flask                  Flask
# 3                    NaN         Angular;jQuery         Angular;jQuery
# 4                    NaN                  Flask                  Flask
#
#                   MiscTechHaveWorkedWith  \
# 0                                    NaN
# 1                                Cordova
# 2  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                    NaN
# 4       Apache Spark;Hadoop;NumPy;Pandas
#
#                         MiscTechWantToWorkWith     ToolsTechHaveWorkedWith  \
# 0                                          NaN                         NaN
# 1                                          NaN             Docker;Git;Yarn
# 2  Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch                         NaN
# 3                                          NaN                         NaN
# 4                          Hadoop;NumPy;Pandas  Docker;Git;Kubernetes;Yarn
#
#       ToolsTechWantToWorkWith  \
# 0                         NaN
# 1                         Git
# 2                         NaN
# 3                         NaN
# 4  Docker;Git;Kubernetes;Yarn
#
#                         NEWCollabToolsHaveWorkedWith  \
# 0                                     PHPStorm;Xcode
# 1          Android Studio;IntelliJ;Notepad++;PyCharm
# 2  IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 3                                                NaN
# 4         Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
#
#                         NEWCollabToolsWantToWorkWith        OpSys  \
# 0                                         Atom;Xcode        MacOS
# 1                                                NaN      Windows
# 2  IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 3                                                NaN      Windows
# 4  Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
#
#                                             NEWStuck  \
# 0  Call a coworker or friend;Visit Stack Overflow...
# 1                     Visit Stack Overflow;Google it
# 2  Visit Stack Overflow;Google it;Watch help / tu...
# 3  Call a coworker or friend;Visit Stack Overflow...
# 4  Visit Stack Overflow;Go for a walk or other ph...
#
#                       NEWSOSites             SOVisitFreq SOAccount  \
# 0                 Stack Overflow  Multiple times per day       Yes
# 1                 Stack Overflow   Daily or almost daily       Yes
# 2  Stack Overflow;Stack Exchange  Multiple times per day       Yes
# 3                 Stack Overflow   Daily or almost daily       Yes
# 4  Stack Overflow;Stack Exchange   Daily or almost daily       Yes
#
#                         SOPartFreq           SOComm NEWOtherComms  \
# 0  A few times per month or weekly  Yes, definitely            No
# 1            Daily or almost daily  Yes, definitely            No
# 2           Multiple times per day  Yes, definitely           Yes
# 3            Daily or almost daily          Neutral            No
# 4             A few times per week    Yes, somewhat            No
#
#                Age Gender Trans                Sexuality  \
# 0  25-34 years old    Man    No  Straight / Heterosexual
# 1  18-24 years old    Man    No  Straight / Heterosexual
# 2  18-24 years old    Man    No        Prefer not to say
# 3  35-44 years old    Man    No  Straight / Heterosexual
# 4  25-34 years old    Man    No                      NaN
#
#                       Ethnicity                Accessibility  \
# 0  White or of European descent            None of the above
# 1  White or of European descent            None of the above
# 2             Prefer not to say            None of the above
# 3  White or of European descent  I am deaf / hard of hearing
# 4  White or of European descent            None of the above
#
#         MentalHealth           SurveyLength                  SurveyEase  \
# 0  None of the above  Appropriate in length                        Easy
# 1  None of the above  Appropriate in length                        Easy
# 2  None of the above  Appropriate in length                        Easy
# 3                NaN  Appropriate in length  Neither easy nor difficult
# 4                NaN  Appropriate in length                        Easy
#
#    ConvertedCompYearly
# 0              62268.0
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %%
df.head(100)
# Out:
#     ResponseId                                         MainBranch  \
# 0            1                     I am a developer by profession
# 1            2             I am a student who is learning to code
# 2            3  I am not primarily a developer, but I write co...
# 3            4                     I am a developer by profession
# 4            5                     I am a developer by profession
# ..         ...                                                ...
# 95          96                     I am a developer by profession
# 96          97                     I am a developer by profession
# 97          98                     I am a developer by profession
# 98          99                     I am a developer by profession
# 99         100                     I am a developer by profession
#
#                                            Employment  \
# 0   Independent contractor, freelancer, or self-em...
# 1                                  Student, full-time
# 2                                  Student, full-time
# 3                                  Employed full-time
# 4   Independent contractor, freelancer, or self-em...
# ..                                                ...
# 95                                 Employed full-time
# 96                                 Employed full-time
# 97                                 Employed full-time
# 98                                 Employed full-time
# 99                                 Employed full-time
#
#                                               Country US_State UK_Country  \
# 0                                            Slovakia      NaN        NaN
# 1                                         Netherlands      NaN        NaN
# 2                                  Russian Federation      NaN        NaN
# 3                                             Austria      NaN        NaN
# 4   United Kingdom of Great Britain and Northern I...      NaN    England
# ..                                                ...      ...        ...
# 95                                              Italy      NaN        NaN
# 96                                            Germany      NaN        NaN
# 97                                             Poland      NaN        NaN
# 98                                              India      NaN        NaN
# 99                                             Sweden      NaN        NaN
#
#                                               EdLevel     Age1stCode  \
# 0   Secondary school (e.g. American high school, G...  18 - 24 years
# 1        Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 2        Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 3     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  11 - 17 years
# 4     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)   5 - 10 years
# ..                                                ...            ...
# 95       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 96       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 97       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 98       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  18 - 24 years
# 99    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  18 - 24 years
#
#                                             LearnCode YearsCode  \
# 0   Coding Bootcamp;Other online resources (ex: vi...       NaN
# 1   Other online resources (ex: videos, blogs, etc...         7
# 2   Other online resources (ex: videos, blogs, etc...       NaN
# 3                                                 NaN       NaN
# 4                             Friend or family member        17
# ..                                                ...       ...
# 95  Other online resources (ex: videos, blogs, etc...        25
# 96                            Other (please specify):        10
# 97  Other online resources (ex: videos, blogs, etc...        10
# 98  Other online resources (ex: videos, blogs, etc...         3
# 99                                             School        10
#
#         YearsCodePro                                            DevType  \
# 0                NaN                                  Developer, mobile
# 1                NaN                                                NaN
# 2                NaN                                                NaN
# 3                NaN                               Developer, front-end
# 4                 10  Developer, desktop or enterprise applications;...
# ..               ...                                                ...
# 95                21  Developer, front-end;Developer, full-stack;Dev...
# 96  Less than 1 year                              Developer, full-stack
# 97                 4  Developer, front-end;Developer, full-stack;Dev...
# 98  Less than 1 year  Developer, mobile;Developer, front-end;Develop...
# 99                 7                 Engineer, data;Developer, back-end
#
#                                               OrgSize             Currency  \
# 0                                  20 to 99 employees    EUR European Euro
# 1                                                 NaN                  NaN
# 2                                                 NaN                  NaN
# 3                                100 to 499 employees    EUR European Euro
# 4   Just me - I am a freelancer, sole proprietor, ...  GBP\tPound sterling
# ..                                                ...                  ...
# 95                               100 to 499 employees    EUR European Euro
# 96                               100 to 499 employees    EUR European Euro
# 97                                   2 to 9 employees    PLN\tPolish zloty
# 98                                 20 to 99 employees    INR\tIndian rupee
# 99                                 20 to 99 employees   SEK\tSwedish krona
#
#     CompTotal CompFreq                             LanguageHaveWorkedWith  \
# 0      4800.0  Monthly      C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1         NaN      NaN                                  JavaScript;Python
# 2         NaN      NaN                           Assembly;C;Python;R;Rust
# 3         NaN  Monthly                              JavaScript;TypeScript
# 4         NaN      NaN                     Bash/Shell;HTML/CSS;Python;SQL
# ..        ...      ...                                                ...
# 95        NaN      NaN  C#;HTML/CSS;Java;JavaScript;Node.js;SQL;TypeSc...
# 96    40000.0  Monthly  Bash/Shell;Clojure;Haskell;Java;JavaScript;Kot...
# 97     9000.0  Monthly     HTML/CSS;JavaScript;Node.js;PHP;SQL;TypeScript
# 98        NaN  Monthly                                                NaN
# 99    51000.0   Yearly                                              Scala
#
#                                LanguageWantToWorkWith  \
# 0                                               Swift
# 1                                                 NaN
# 2                                   Julia;Python;Rust
# 3                               JavaScript;TypeScript
# 4                      Bash/Shell;HTML/CSS;Python;SQL
# ..                                                ...
# 95  C#;HTML/CSS;Java;JavaScript;Node.js;SQL;TypeSc...
# 96                                            Haskell
# 97             HTML/CSS;JavaScript;Node.js;TypeScript
# 98                                                NaN
# 99                                              Scala
#
#                         DatabaseHaveWorkedWith  \
# 0                            PostgreSQL;SQLite
# 1                                   PostgreSQL
# 2                                       SQLite
# 3                                          NaN
# 4               Elasticsearch;PostgreSQL;Redis
# ..                                         ...
# 95  Microsoft SQL Server;MongoDB;Oracle;SQLite
# 96                                   Cassandra
# 97    Firebase;MongoDB;MySQL;PostgreSQL;SQLite
# 98                                         NaN
# 99                                     MongoDB
#
#                         DatabaseWantToWorkWith  \
# 0                                       SQLite
# 1                                          NaN
# 2                                       SQLite
# 3                                          NaN
# 4     Cassandra;Elasticsearch;PostgreSQL;Redis
# ..                                         ...
# 95  Microsoft SQL Server;MongoDB;Oracle;SQLite
# 96                                         NaN
# 97                                         NaN
# 98                                         NaN
# 99                                     MongoDB
#
#                            PlatformHaveWorkedWith PlatformWantToWorkWith  \
# 0                                             NaN                    NaN
# 1                                             NaN                    NaN
# 2                                          Heroku                    NaN
# 3                                             NaN                    NaN
# 4                                             NaN                    NaN
# ..                                            ...                    ...
# 95                                            NaN                    NaN
# 96                      AWS;Google Cloud Platform                    NaN
# 97  AWS;DigitalOcean;Google Cloud Platform;Heroku                    NaN
# 98                                            NaN                    NaN
# 99                          Google Cloud Platform                    AWS
#
#                   WebframeHaveWorkedWith WebframeWantToWorkWith  \
# 0                        Laravel;Symfony                    NaN
# 1                   Angular;Flask;Vue.js                    NaN
# 2                                  Flask                  Flask
# 3                         Angular;jQuery         Angular;jQuery
# 4                                  Flask                  Flask
# ..                                   ...                    ...
# 95  Angular;ASP.NET;ASP.NET Core ;jQuery  Angular;ASP.NET Core
# 96                              React.js                    NaN
# 97                      Laravel;React.js               React.js
# 98                                   NaN                    NaN
# 99                                   NaN                    NaN
#
#                    MiscTechHaveWorkedWith  \
# 0                                     NaN
# 1                                 Cordova
# 2   NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                     NaN
# 4        Apache Spark;Hadoop;NumPy;Pandas
# ..                                    ...
# 95      .NET Framework;.NET Core / .NET 5
# 96                                Flutter
# 97                                    NaN
# 98                                    NaN
# 99                                    NaN
#
#                          MiscTechWantToWorkWith  \
# 0                                           NaN
# 1                                           NaN
# 2   Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                           NaN
# 4                           Hadoop;NumPy;Pandas
# ..                                          ...
# 95            .NET Framework;.NET Core / .NET 5
# 96                                          NaN
# 97                                          NaN
# 98                                          NaN
# 99                                          NaN
#
#            ToolsTechHaveWorkedWith         ToolsTechWantToWorkWith  \
# 0                              NaN                             NaN
# 1                  Docker;Git;Yarn                             Git
# 2                              NaN                             NaN
# 3                              NaN                             NaN
# 4       Docker;Git;Kubernetes;Yarn      Docker;Git;Kubernetes;Yarn
# ..                             ...                             ...
# 95  Ansible;Git;Kubernetes;Xamarin  Ansible;Git;Kubernetes;Xamarin
# 96           Docker;Git;Kubernetes                             Git
# 97       Docker;Git;Terraform;Yarn                      Docker;Git
# 98                             NaN                             NaN
# 99                             Git                             Git
#
#                          NEWCollabToolsHaveWorkedWith  \
# 0                                      PHPStorm;Xcode
# 1           Android Studio;IntelliJ;Notepad++;PyCharm
# 2   IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 3                                                 NaN
# 4          Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
# ..                                                ...
# 95  Android Studio;Notepad++;Visual Studio;Visual ...
# 96                                   Emacs;Neovim;Vim
# 97                             Vim;Visual Studio Code
# 98                                                NaN
# 99                                           IntelliJ
#
#                          NEWCollabToolsWantToWorkWith        OpSys  \
# 0                                          Atom;Xcode        MacOS
# 1                                                 NaN      Windows
# 2   IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 3                                                 NaN      Windows
# 4   Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
# ..                                                ...          ...
# 95         Notepad++;Visual Studio;Visual Studio Code      Windows
# 96                                   Emacs;Neovim;Vim  Linux-based
# 97                                 Visual Studio Code      Windows
# 98                                                NaN  Linux-based
# 99                                           IntelliJ        MacOS
#
#                                              NEWStuck  \
# 0   Call a coworker or friend;Visit Stack Overflow...
# 1                      Visit Stack Overflow;Google it
# 2   Visit Stack Overflow;Google it;Watch help / tu...
# 3   Call a coworker or friend;Visit Stack Overflow...
# 4   Visit Stack Overflow;Go for a walk or other ph...
# ..                                                ...
# 95  Visit Stack Overflow;Google it;Watch help / tu...
# 96                    Call a coworker or friend;Panic
# 97                     Visit Stack Overflow;Google it
# 98                     Visit Stack Overflow;Google it
# 99                                          Google it
#
#                                            NEWSOSites             SOVisitFreq  \
# 0                                      Stack Overflow  Multiple times per day
# 1                                      Stack Overflow   Daily or almost daily
# 2                       Stack Overflow;Stack Exchange  Multiple times per day
# 3                                      Stack Overflow   Daily or almost daily
# 4                       Stack Overflow;Stack Exchange   Daily or almost daily
# ..                                                ...                     ...
# 95                      Stack Overflow;Stack Exchange  Multiple times per day
# 96                      Stack Overflow;Stack Exchange    A few times per week
# 97                      Stack Overflow;Stack Exchange  Multiple times per day
# 98                      Stack Overflow;Stack Exchange  Multiple times per day
# 99  Stack Overflow;Stack Exchange;Stack Overflow f...  Multiple times per day
#
#    SOAccount                                         SOPartFreq  \
# 0        Yes                    A few times per month or weekly
# 1        Yes                              Daily or almost daily
# 2        Yes                             Multiple times per day
# 3        Yes                              Daily or almost daily
# 4        Yes                               A few times per week
# ..       ...                                                ...
# 95       Yes  I have never participated in Q&A on Stack Over...
# 96       Yes                Less than once per month or monthly
# 97       Yes  I have never participated in Q&A on Stack Over...
# 98       Yes                               A few times per week
# 99       Yes                              Daily or almost daily
#
#              SOComm NEWOtherComms              Age  \
# 0   Yes, definitely            No  25-34 years old
# 1   Yes, definitely            No  18-24 years old
# 2   Yes, definitely           Yes  18-24 years old
# 3           Neutral            No  35-44 years old
# 4     Yes, somewhat            No  25-34 years old
# ..              ...           ...              ...
# 95    Yes, somewhat           Yes  35-44 years old
# 96   No, not really           Yes  18-24 years old
# 97    Yes, somewhat            No  18-24 years old
# 98  Yes, definitely            No  18-24 years old
# 99  Yes, definitely           Yes  25-34 years old
#
#                                                Gender Trans  \
# 0                                                 Man    No
# 1                                                 Man    No
# 2                                                 Man    No
# 3                                                 Man    No
# 4                                                 Man    No
# ..                                                ...   ...
# 95                                                Man    No
# 96  Non-binary, genderqueer, or gender non-conforming   Yes
# 97                                                Man    No
# 98                                                Man    No
# 99                                                Man    No
#
#                   Sexuality                     Ethnicity  \
# 0   Straight / Heterosexual  White or of European descent
# 1   Straight / Heterosexual  White or of European descent
# 2         Prefer not to say             Prefer not to say
# 3   Straight / Heterosexual  White or of European descent
# 4                       NaN  White or of European descent
# ..                      ...                           ...
# 95                      NaN  White or of European descent
# 96           Bisexual;Queer  White or of European descent
# 97           Gay or Lesbian  White or of European descent
# 98  Straight / Heterosexual                    East Asian
# 99  Straight / Heterosexual  White or of European descent
#
#                   Accessibility  \
# 0             None of the above
# 1             None of the above
# 2             None of the above
# 3   I am deaf / hard of hearing
# 4             None of the above
# ..                          ...
# 95            None of the above
# 96            None of the above
# 97            None of the above
# 98            None of the above
# 99            None of the above
#
#                                          MentalHealth           SurveyLength  \
# 0                                   None of the above  Appropriate in length
# 1                                   None of the above  Appropriate in length
# 2                                   None of the above  Appropriate in length
# 3                                                 NaN  Appropriate in length
# 4                                                 NaN  Appropriate in length
# ..                                                ...                    ...
# 95                                  None of the above               Too long
# 96  I have a mood or emotional disorder (e.g. depr...  Appropriate in length
# 97                                  None of the above  Appropriate in length
# 98                                  None of the above               Too long
# 99                                  None of the above  Appropriate in length
#
#                     SurveyEase  ConvertedCompYearly
# 0                         Easy              62268.0
# 1                         Easy                  NaN
# 2                         Easy                  NaN
# 3   Neither easy nor difficult                  NaN
# 4                         Easy                  NaN
# ..                         ...                  ...
# 95  Neither easy nor difficult                  NaN
# 96                        Easy             518868.0
# 97                        Easy              27336.0
# 98                        Easy                  NaN
# 99                        Easy               5216.0
#
# [100 rows x 48 columns]

# %%
df.tail(10)
# Out:
#        ResponseId                      MainBranch  \
# 83429       83430     I code primarily as a hobby
# 83430       83431  I am a developer by profession
# 83431       83432  I am a developer by profession
# 83432       83433  I am a developer by profession
# 83433       83434  I am a developer by profession
# 83434       83435  I am a developer by profession
# 83435       83436  I am a developer by profession
# 83436       83437  I am a developer by profession
# 83437       83438  I am a developer by profession
# 83438       83439  I am a developer by profession
#
#                                               Employment  \
# 83429                 Not employed, but looking for work
# 83430                                 Employed full-time
# 83431  Independent contractor, freelancer, or self-em...
# 83432                                 Employed full-time
# 83433  Independent contractor, freelancer, or self-em...
# 83434                                 Employed full-time
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
# 83438                                 Employed full-time
#
#                         Country    US_State UK_Country  \
# 83429  United States of America  Washington        NaN
# 83430  United States of America    Illinois        NaN
# 83431                  Pakistan         NaN        NaN
# 83432                    Canada         NaN        NaN
# 83433                    Brazil         NaN        NaN
# 83434  United States of America       Texas        NaN
# 83435                     Benin         NaN        NaN
# 83436  United States of America  New Jersey        NaN
# 83437                    Canada         NaN        NaN
# 83438                    Brazil         NaN        NaN
#
#                                                  EdLevel     Age1stCode  \
# 83429       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  18 - 24 years
# 83430    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  11 - 17 years
# 83431       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 83432       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  18 - 24 years
# 83433       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  18 - 24 years
# 83434       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 83435       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 83436  Secondary school (e.g. American high school, G...  11 - 17 years
# 83437       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 83438                 Professional degree (JD, MD, etc.)  11 - 17 years
#
#                                                LearnCode YearsCode  \
# 83429    Other online resources (ex: videos, blogs, etc)         6
# 83430  Other online resources (ex: videos, blogs, etc...        23
# 83431  Other online resources (ex: videos, blogs, etc...         9
# 83432                                             School         5
# 83433  Online Forum;Online Courses or Certification;O...        15
# 83434  Other online resources (ex: videos, blogs, etc...         6
# 83435  Other online resources (ex: videos, blogs, etc...         4
# 83436                                             School        10
# 83437  Online Courses or Certification;Books / Physic...         5
# 83438                                             School        14
#
#            YearsCodePro                                            DevType  \
# 83429               NaN                    Other (please specify):;Student
# 83430                21  Developer, front-end;Developer, full-stack;Dev...
# 83431                 4  Developer, mobile;Developer, desktop or enterp...
# 83432  Less than 1 year                                Developer, back-end
# 83433                11  Developer, mobile;Developer, front-end;Develop...
# 83434                 5                                Developer, back-end
# 83435                 2                              Developer, full-stack
# 83436                 4  Data scientist or machine learning specialist;...
# 83437                 3                                Developer, back-end
# 83438                 4  Developer, front-end;Developer, full-stack;Dev...
#
#                                                  OrgSize  \
# 83429                                                NaN
# 83430                                 10 to 19 employees
# 83431                                   2 to 9 employees
# 83432                           10,000 or more employees
# 83433                           1,000 to 4,999 employees
# 83434                                 20 to 99 employees
# 83435  Just me - I am a freelancer, sole proprietor, ...
# 83436                           10,000 or more employees
# 83437                                 20 to 99 employees
# 83438                                       I don’t know
#
#                           Currency  CompTotal CompFreq  \
# 83429                          NaN        NaN      NaN
# 83430    USD\tUnited States dollar   125000.0   Yearly
# 83431         PKR\tPakistani rupee   150000.0  Monthly
# 83432         CAD\tCanadian dollar   106000.0   Yearly
# 83433          BRL\tBrazilian real    80000.0   Yearly
# 83434    USD\tUnited States dollar   160500.0   Yearly
# 83435  XOF\tWest African CFA franc   200000.0  Monthly
# 83436    USD\tUnited States dollar     1800.0   Weekly
# 83437         CAD\tCanadian dollar    90000.0  Monthly
# 83438          BRL\tBrazilian real     7700.0  Monthly
#
#                                   LanguageHaveWorkedWith  \
# 83429             HTML/CSS;PHP;PowerShell;Python;SQL;VBA
# 83430        APL;Clojure;LISP;Python;Ruby;SQL;TypeScript
# 83431  C#;Dart;HTML/CSS;Java;JavaScript;Kotlin;Node.j...
# 83432                                               Ruby
# 83433      Java;JavaScript;Kotlin;Objective-C;TypeScript
# 83434                                 Clojure;Kotlin;SQL
# 83435                                                NaN
# 83436                                 Groovy;Java;Python
# 83437               Bash/Shell;JavaScript;Node.js;Python
# 83438             Delphi;Elixir;HTML/CSS;Java;JavaScript
#
#                                   LanguageWantToWorkWith  \
# 83429  C#;Go;HTML/CSS;Java;JavaScript;PHP;Python;SQL;VBA
# 83430                         APL;Clojure;Haskell;LISP;R
# 83431  C#;Dart;HTML/CSS;JavaScript;Kotlin;Node.js;Pyt...
# 83432                               Java;Ruby;TypeScript
# 83433                                             Kotlin
# 83434                                            Clojure
# 83435                                                NaN
# 83436                                        Java;Python
# 83437                                            Go;Rust
# 83438  Elixir;HTML/CSS;Java;JavaScript;Node.js;PHP;SQ...
#
#                                  DatabaseHaveWorkedWith  \
# 83429                          MongoDB;MySQL;PostgreSQL
# 83430                    MongoDB;MySQL;PostgreSQL;Redis
# 83431                             Firebase;MySQL;SQLite
# 83432                                  MySQL;PostgreSQL
# 83433                     Firebase;MongoDB;MySQL;SQLite
# 83434                                     Oracle;SQLite
# 83435    Firebase;MariaDB;MySQL;PostgreSQL;Redis;SQLite
# 83436   DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83437  Cassandra;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83438                                 Oracle;PostgreSQL
#
#                                   DatabaseWantToWorkWith  \
# 83429  MariaDB;Microsoft SQL Server;MongoDB;MySQL;Pos...
# 83430                                         PostgreSQL
# 83431             DynamoDB;Firebase;MongoDB;MySQL;SQLite
# 83432                                                NaN
# 83433                                                NaN
# 83434                                             SQLite
# 83435  Firebase;MariaDB;MongoDB;MySQL;PostgreSQL;Redi...
# 83436                                     DynamoDB;Redis
# 83437                                                NaN
# 83438  Elasticsearch;MongoDB;MySQL;Oracle;PostgreSQL;...
#
#                               PlatformHaveWorkedWith  \
# 83429                                         Heroku
# 83430  AWS;DigitalOcean;Google Cloud Platform;Heroku
# 83431                          Google Cloud Platform
# 83432                   Google Cloud Platform;Heroku
# 83433                                            NaN
# 83434                                            AWS
# 83435                                            NaN
# 83436                      AWS;Google Cloud Platform
# 83437                                         Heroku
# 83438                                Microsoft Azure
#
#                                   PlatformWantToWorkWith  \
# 83429  AWS;Heroku;IBM Cloud or Watson;Microsoft Azure...
# 83430             AWS;DigitalOcean;Google Cloud Platform
# 83431                          AWS;Google Cloud Platform
# 83432                                                NaN
# 83433                                                NaN
# 83434                                                AWS
# 83435                                                NaN
# 83436                                                AWS
# 83437                                   AWS;DigitalOcean
# 83438                                                AWS
#
#                              WebframeHaveWorkedWith  \
# 83429                           Django;Flask;jQuery
# 83430                 Django;React.js;Ruby on Rails
# 83431                                  Flask;jQuery
# 83432           Flask;React.js;Ruby on Rails;Vue.js
# 83433                                      React.js
# 83434                                           NaN
# 83435  Django;jQuery;Laravel;React.js;Ruby on Rails
# 83436                                 FastAPI;Flask
# 83437                 Django;Express;Flask;React.js
# 83438                                Angular;Spring
#
#                                   WebframeWantToWorkWith  \
# 83429  Angular.js;ASP.NET;ASP.NET Core ;Django;FastAP...
# 83430                                                NaN
# 83431                Angular;Django;Flask;jQuery;Laravel
# 83432                                                NaN
# 83433                                                NaN
# 83434                                                NaN
# 83435  Django;Express;jQuery;Laravel;React.js;Ruby on...
# 83436                                      FastAPI;Flask
# 83437                                                NaN
# 83438                     Express;Laravel;Spring;Symfony
#
#                       MiscTechHaveWorkedWith  \
# 83429                           NumPy;Pandas
# 83430                                    NaN
# 83431                                Flutter
# 83432  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83433                           React Native
# 83434                                    NaN
# 83435                             Flutter;Qt
# 83436              Hadoop;Keras;NumPy;Pandas
# 83437  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                    NaN
#
#                                   MiscTechWantToWorkWith  \
# 83429     .NET Framework;.NET Core / .NET 5;NumPy;Pandas
# 83430                                                NaN
# 83431      Flutter;Hadoop;NumPy;TensorFlow;Torch/PyTorch
# 83432                                                NaN
# 83433                                            Flutter
# 83434                                                NaN
# 83435                                                NaN
# 83436  Apache Spark;Hadoop;Keras;NumPy;Pandas;TensorFlow
# 83437              NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                                NaN
#
#             ToolsTechHaveWorkedWith          ToolsTechWantToWorkWith  \
# 83429                           Git               Docker;Git;Xamarin
# 83430                    Docker;Git   Docker;Git;Kubernetes;Unity 3D
# 83431                           Git                       Docker;Git
# 83432    Docker;Git;Kubernetes;Yarn                              NaN
# 83433               Docker;Git;Yarn                       Docker;Git
# 83434                    Docker;Git                   Git;Kubernetes
# 83435    Git;Unity 3D;Unreal Engine            Docker;Git;Kubernetes
# 83436  Ansible;Docker;Git;Terraform  Docker;Git;Kubernetes;Terraform
# 83437  Ansible;Docker;Git;Terraform             Kubernetes;Terraform
# 83438                    Docker;Git            Docker;Git;Kubernetes
#
#                             NEWCollabToolsHaveWorkedWith  \
# 83429     Atom;Notepad++;Sublime Text;Visual Studio Code
# 83430                                          Emacs;Vim
# 83431  Android Studio;IntelliJ;IPython/Jupyter;Notepa...
# 83432        Atom;IPython/Jupyter;Vim;Visual Studio Code
# 83433            Android Studio;Visual Studio Code;Xcode
# 83434       IntelliJ;Sublime Text;Vim;Visual Studio Code
# 83435  Android Studio;Eclipse;Emacs;IntelliJ;NetBeans...
# 83436  Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
# 83437                               PyCharm;Sublime Text
# 83438                        IntelliJ;Visual Studio Code
#
#                             NEWCollabToolsWantToWorkWith        OpSys  \
# 83429     Atom;Notepad++;Sublime Text;Visual Studio Code      Windows
# 83430                                              Emacs  Linux-based
# 83431  Android Studio;IntelliJ;IPython/Jupyter;PyChar...      Windows
# 83432                                                NaN        MacOS
# 83433                               Android Studio;Xcode        MacOS
# 83434                                   Sublime Text;Vim        MacOS
# 83435  Emacs;IntelliJ;PHPStorm;PyCharm;RStudio;Sublim...  Linux-based
# 83436             IntelliJ;IPython/Jupyter;Notepad++;Vim      Windows
# 83437                                                NaN        MacOS
# 83438               IntelliJ;PHPStorm;Visual Studio Code  Linux-based
#
#                                                 NEWStuck  \
# 83429  Visit Stack Overflow;Google it;Watch help / tu...
# 83430  Call a coworker or friend;Visit Stack Overflow...
# 83431  Visit Stack Overflow;Go for a walk or other ph...
# 83432  Visit Stack Overflow;Go for a walk or other ph...
# 83433  Call a coworker or friend;Visit Stack Overflow...
# 83434                Call a coworker or friend;Google it
# 83435  Call a coworker or friend;Visit Stack Overflow...
# 83436  Call a coworker or friend;Visit Stack Overflow...
# 83437  Call a coworker or friend;Visit Stack Overflow...
# 83438  Call a coworker or friend;Visit Stack Overflow...
#
#                                               NEWSOSites  \
# 83429                      Stack Overflow;Stack Exchange
# 83430                      Stack Overflow;Stack Exchange
# 83431                      Stack Overflow;Stack Exchange
# 83432                      Stack Overflow;Stack Exchange
# 83433                                     Stack Overflow
# 83434                      Stack Overflow;Stack Exchange
# 83435                      Stack Overflow;Stack Exchange
# 83436                      Stack Overflow;Stack Exchange
# 83437                                     Stack Overflow
# 83438  Stack Overflow;Stack Exchange;Stack Overflow f...
#
#                            SOVisitFreq                SOAccount  \
# 83429  A few times per month or weekly  Not sure/can't remember
# 83430             A few times per week                       No
# 83431           Multiple times per day                      Yes
# 83432            Daily or almost daily                       No
# 83433            Daily or almost daily                      Yes
# 83434             A few times per week                       No
# 83435           Multiple times per day                      Yes
# 83436             A few times per week                      Yes
# 83437  A few times per month or weekly                      Yes
# 83438             A few times per week                      Yes
#
#                                               SOPartFreq           SOComm  \
# 83429                                                NaN    Yes, somewhat
# 83430                                                NaN   No, not really
# 83431                    A few times per month or weekly  Yes, definitely
# 83432                                                NaN   No, not really
# 83433                    A few times per month or weekly    Yes, somewhat
# 83434                                                NaN   No, not at all
# 83435  I have never participated in Q&A on Stack Over...    Yes, somewhat
# 83436  I have never participated in Q&A on Stack Over...   No, not really
# 83437                Less than once per month or monthly   No, not really
# 83438                               A few times per week    Yes, somewhat
#
#       NEWOtherComms              Age                      Gender Trans  \
# 83429            No  25-34 years old  Man;Or, in your own words:   Yes
# 83430            No  45-54 years old                         Man    No
# 83431            No  18-24 years old                         Man    No
# 83432            No  18-24 years old                       Woman    No
# 83433            No  25-34 years old                         Man    No
# 83434            No  25-34 years old                         Man    No
# 83435            No  18-24 years old                         Man    No
# 83436            No  25-34 years old                         Man    No
# 83437            No  25-34 years old                         Man    No
# 83438            No  18-24 years old                         Man    No
#
#                      Sexuality                     Ethnicity  \
# 83429                    Queer  White or of European descent
# 83430  Straight / Heterosexual  White or of European descent
# 83431  Straight / Heterosexual               Southeast Asian
# 83432  Straight / Heterosexual                    East Asian
# 83433  Straight / Heterosexual        Hispanic or Latino/a/x
# 83434  Straight / Heterosexual  White or of European descent
# 83435  Straight / Heterosexual   Black or of African descent
# 83436                      NaN  White or of European descent
# 83437  Straight / Heterosexual  White or of European descent
# 83438  Straight / Heterosexual        Hispanic or Latino/a/x
#
#                                            Accessibility  \
# 83429  I am unable to / find it difficult to walk or ...
# 83430                                  None of the above
# 83431                                  None of the above
# 83432                                  None of the above
# 83433                                  None of the above
# 83434                                  None of the above
# 83435                                  None of the above
# 83436                                  None of the above
# 83437                                  None of the above
# 83438                                  None of the above
#
#                                             MentalHealth  \
# 83429                         I have an anxiety disorder
# 83430                                  None of the above
# 83431                                  None of the above
# 83432                                  None of the above
# 83433                         I have an anxiety disorder
# 83434  I have a concentration and/or memory disorder ...
# 83435                                  None of the above
# 83436                                  None of the above
# 83437  I have a mood or emotional disorder (e.g. depr...
# 83438                                  None of the above
#
#                 SurveyLength                  SurveyEase  ConvertedCompYearly
# 83429  Appropriate in length  Neither easy nor difficult                  NaN
# 83430  Appropriate in length                        Easy             125000.0
# 83431  Appropriate in length                        Easy              11676.0
# 83432  Appropriate in length                        Easy              80169.0
# 83433  Appropriate in length                        Easy              18326.0
# 83434  Appropriate in length                        Easy             160500.0
# 83435  Appropriate in length                        Easy               3960.0
# 83436  Appropriate in length  Neither easy nor difficult              90000.0
# 83437  Appropriate in length  Neither easy nor difficult             816816.0
# 83438  Appropriate in length                        Easy              21168.0

# %%
df.head(40)
# Out:
#     ResponseId                                         MainBranch  \
# 0            1                     I am a developer by profession
# 1            2             I am a student who is learning to code
# 2            3  I am not primarily a developer, but I write co...
# 3            4                     I am a developer by profession
# 4            5                     I am a developer by profession
# 5            6             I am a student who is learning to code
# 6            7                        I code primarily as a hobby
# 7            8             I am a student who is learning to code
# 8            9                     I am a developer by profession
# 9           10                     I am a developer by profession
# 10          11                     I am a developer by profession
# 11          12                     I am a developer by profession
# 12          13                     I am a developer by profession
# 13          14             I am a student who is learning to code
# 14          15  I used to be a developer by profession, but no...
# 15          16             I am a student who is learning to code
# 16          17                     I am a developer by profession
# 17          18                     I am a developer by profession
# 18          19  I am not primarily a developer, but I write co...
# 19          20  I used to be a developer by profession, but no...
# 20          21                     I am a developer by profession
# 21          22             I am a student who is learning to code
# 22          23             I am a student who is learning to code
# 23          24                     I am a developer by profession
# 24          25                     I am a developer by profession
# 25          26  I am not primarily a developer, but I write co...
# 26          27  I am not primarily a developer, but I write co...
# 27          28                     I am a developer by profession
# 28          29                     I am a developer by profession
# 29          30                     I am a developer by profession
# 30          31                        I code primarily as a hobby
# 31          32                     I am a developer by profession
# 32          33                     I am a developer by profession
# 33          34                     I am a developer by profession
# 34          35                     I am a developer by profession
# 35          36                     I am a developer by profession
# 36          37                     I am a developer by profession
# 37          38                     I am a developer by profession
# 38          39             I am a student who is learning to code
# 39          40             I am a student who is learning to code
#
#                                            Employment  \
# 0   Independent contractor, freelancer, or self-em...
# 1                                  Student, full-time
# 2                                  Student, full-time
# 3                                  Employed full-time
# 4   Independent contractor, freelancer, or self-em...
# 5                                  Student, part-time
# 6                                 I prefer not to say
# 7                                  Student, full-time
# 8                                  Employed part-time
# 9                                  Employed full-time
# 10                                 Employed full-time
# 11                                 Employed full-time
# 12                                 Employed full-time
# 13                                 Employed full-time
# 14                 Not employed, but looking for work
# 15                                 Student, full-time
# 16                                 Employed full-time
# 17                                 Employed full-time
# 18                                I prefer not to say
# 19                                 Employed full-time
# 20                                 Student, full-time
# 21                                 Student, full-time
# 22                                 Student, full-time
# 23                                 Employed full-time
# 24                                 Employed full-time
# 25                                 Employed full-time
# 26                                 Employed full-time
# 27                                 Employed full-time
# 28  Independent contractor, freelancer, or self-em...
# 29                                 Employed full-time
# 30                                I prefer not to say
# 31                                 Employed full-time
# 32                 Not employed, but looking for work
# 33                                 Employed full-time
# 34                                 Employed full-time
# 35                                 Employed full-time
# 36                                 Employed full-time
# 37                                 Employed full-time
# 38                 Not employed, but looking for work
# 39                                 Student, part-time
#
#                                               Country              US_State  \
# 0                                            Slovakia                   NaN
# 1                                         Netherlands                   NaN
# 2                                  Russian Federation                   NaN
# 3                                             Austria                   NaN
# 4   United Kingdom of Great Britain and Northern I...                   NaN
# 5                            United States of America               Georgia
# 6                            United States of America         New Hampshire
# 7                                            Malaysia                   NaN
# 8                                               India                   NaN
# 9                                              Sweden                   NaN
# 10  United Kingdom of Great Britain and Northern I...                   NaN
# 11                                              Spain                   NaN
# 12                                            Germany                   NaN
# 13                                               Peru                   NaN
# 14  United Kingdom of Great Britain and Northern I...                   NaN
# 15                           United States of America              Missouri
# 16                                             Turkey                   NaN
# 17                                             Canada                   NaN
# 18                                          Singapore                   NaN
# 19                                             Brazil                   NaN
# 20                                            Germany                   NaN
# 21                                             Sweden                   NaN
# 22                                              India                   NaN
# 23                                             France                   NaN
# 24                                            Germany                   NaN
# 25                                            Germany                   NaN
# 26                                        Switzerland                   NaN
# 27  United Kingdom of Great Britain and Northern I...                   NaN
# 28  United Kingdom of Great Britain and Northern I...                   NaN
# 29                                 Russian Federation                   NaN
# 30                                             Malawi                   NaN
# 31                                             Israel                   NaN
# 32                                             Poland                   NaN
# 33                                             Turkey                   NaN
# 34                                            Ukraine                   NaN
# 35                                            Germany                   NaN
# 36                           United States of America  District of Columbia
# 37                           United States of America         Massachusetts
# 38                                           Viet Nam                   NaN
# 39                                              India                   NaN
#
#    UK_Country                                            EdLevel  \
# 0         NaN  Secondary school (e.g. American high school, G...
# 1         NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2         NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3         NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4     England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5         NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 6         NaN  Secondary school (e.g. American high school, G...
# 7         NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 8         NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 9         NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 10    England       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 11        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 12        NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 13        NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 14    England       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 15        NaN  Secondary school (e.g. American high school, G...
# 16        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 17        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 18        NaN         Other doctoral degree (Ph.D., Ed.D., etc.)
# 19        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 20        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 21        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 22        NaN  Some college/university study without earning ...
# 23        NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 24        NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 25        NaN         Other doctoral degree (Ph.D., Ed.D., etc.)
# 26        NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 27    England       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 28    England  Secondary school (e.g. American high school, G...
# 29        NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 30        NaN                                     Something else
# 31        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 32        NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 33        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 34        NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 35        NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 36        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 37        NaN  Some college/university study without earning ...
# 38        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 39        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#        Age1stCode                                          LearnCode  \
# 0   18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 1   11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 2   11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3   11 - 17 years                                                NaN
# 4    5 - 10 years                            Friend or family member
# 5   11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 6   11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 7   11 - 17 years             School;Online Courses or Certification
# 8   18 - 24 years                                    Coding Bootcamp
# 9   11 - 17 years                                             School
# 10  11 - 17 years    Other online resources (ex: videos, blogs, etc)
# 11  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 12  11 - 17 years                            Other (please specify):
# 13   5 - 10 years                                             School
# 14  11 - 17 years                                             School
# 15   5 - 10 years                            Other (please specify):
# 16   5 - 10 years                                             School
# 17  11 - 17 years                                             School
# 18  11 - 17 years                            Other (please specify):
# 19  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 20  11 - 17 years                                   School;Colleague
# 21  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 22   5 - 10 years                     School;Friend or family member
# 23  11 - 17 years             School;Online Courses or Certification
# 24  11 - 17 years                     School;Friend or family member
# 25  25 - 34 years                       Coding Bootcamp;Online Forum
# 26  11 - 17 years                            Other (please specify):
# 27  11 - 17 years                                    Coding Bootcamp
# 28  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 29  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 30  11 - 17 years    Other online resources (ex: videos, blogs, etc)
# 31  25 - 34 years             School;Online Courses or Certification
# 32  11 - 17 years                                             School
# 33  18 - 24 years                                             School
# 34  11 - 17 years                     School;Friend or family member
# 35  11 - 17 years        School;Online Forum;Other (please specify):
# 36  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 37  18 - 24 years    Other online resources (ex: videos, blogs, etc)
# 38  18 - 24 years                                             School
# 39  11 - 17 years                                             School
#
#    YearsCode      YearsCodePro  \
# 0        NaN               NaN
# 1          7               NaN
# 2        NaN               NaN
# 3        NaN               NaN
# 4         17                10
# 5        NaN               NaN
# 6          3               NaN
# 7          4               NaN
# 8          6                 4
# 9          7                 4
# 10        16                10
# 11        12                 5
# 12        15                 6
# 13        10               NaN
# 14        40               NaN
# 15         7               NaN
# 16         6                 2
# 17         9                 6
# 18        40                30
# 19        12                 9
# 20       NaN               NaN
# 21       NaN               NaN
# 22         7               NaN
# 23         9                 2
# 24        26                18
# 25        12                12
# 26        14                 5
# 27        39                21
# 28        14                 1
# 29        20                16
# 30         4               NaN
# 31         4                 2
# 32         8               NaN
# 33         6                 2
# 34        17                10
# 35        19                10
# 36         8  Less than 1 year
# 37        20                15
# 38         5               NaN
# 39         3               NaN
#
#                                               DevType  \
# 0                                   Developer, mobile
# 1                                                 NaN
# 2                                                 NaN
# 3                                Developer, front-end
# 4   Developer, desktop or enterprise applications;...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                Developer, front-end
# 9       Data scientist or machine learning specialist
# 10                                Developer, back-end
# 11                                Developer, back-end
# 12  Developer, desktop or enterprise applications;...
# 13      Data scientist or machine learning specialist
# 14                                                NaN
# 15                                                NaN
# 16                              Developer, full-stack
# 17  Developer, front-end;Developer, full-stack;Dev...
# 18                                                NaN
# 19                            Other (please specify):
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23  Engineer, data;Data scientist or machine learn...
# 24  Developer, front-end;Developer, desktop or ent...
# 25  Academic researcher;Database administrator;Sci...
# 26              Academic researcher;Scientist;Student
# 27                                Developer, back-end
# 28          Developer, back-end;Developer, QA or test
# 29  Developer, desktop or enterprise applications;...
# 30                                                NaN
# 31                 Engineer, data;Developer, back-end
# 32                              Developer, full-stack
# 33                        Developer, game or graphics
# 34  Developer, mobile;Developer, desktop or enterp...
# 35          Developer, full-stack;Developer, back-end
# 36        Developer, embedded applications or devices
# 37                                Developer, back-end
# 38                               Developer, front-end
# 39                                                NaN
#
#                                               OrgSize  \
# 0                                  20 to 99 employees
# 1                                                 NaN
# 2                                                 NaN
# 3                                100 to 499 employees
# 4   Just me - I am a freelancer, sole proprietor, ...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                            10,000 or more employees
# 9                                  10 to 19 employees
# 10                           10,000 or more employees
# 11                                 10 to 19 employees
# 12                           1,000 to 4,999 employees
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                               100 to 499 employees
# 17                               500 to 999 employees
# 18                           5,000 to 9,999 employees
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                 10 to 19 employees
# 24                           1,000 to 4,999 employees
# 25                               100 to 499 employees
# 26                           5,000 to 9,999 employees
# 27                           5,000 to 9,999 employees
# 28  Just me - I am a freelancer, sole proprietor, ...
# 29                                   2 to 9 employees
# 30                                                NaN
# 31                           5,000 to 9,999 employees
# 32                                                NaN
# 33                                   2 to 9 employees
# 34                                   2 to 9 employees
# 35                               500 to 999 employees
# 36                                 20 to 99 employees
# 37                           1,000 to 4,999 employees
# 38                                                NaN
# 39                                                NaN
#
#                      Currency  CompTotal CompFreq  \
# 0           EUR European Euro     4800.0  Monthly
# 1                         NaN        NaN      NaN
# 2                         NaN        NaN      NaN
# 3           EUR European Euro        NaN  Monthly
# 4         GBP\tPound sterling        NaN      NaN
# 5                         NaN        NaN      NaN
# 6                         NaN        NaN      NaN
# 7                         NaN        NaN      NaN
# 8           INR\tIndian rupee        NaN  Monthly
# 9          SEK\tSwedish krona    42000.0  Monthly
# 10        GBP\tPound sterling        NaN      NaN
# 11          EUR European Euro    43000.0   Yearly
# 12          EUR European Euro    71500.0   Yearly
# 13                        NaN        NaN      NaN
# 14                        NaN        NaN      NaN
# 15                        NaN        NaN      NaN
# 16          TRY\tTurkish lira     9000.0  Monthly
# 17       CAD\tCanadian dollar    61000.0   Yearly
# 18      SGD\tSingapore dollar    18700.0  Monthly
# 19                        NaN        NaN      NaN
# 20                        NaN        NaN      NaN
# 21                        NaN        NaN      NaN
# 22                        NaN        NaN      NaN
# 23          EUR European Euro    36000.0   Yearly
# 24          EUR European Euro    72000.0   Yearly
# 25          EUR European Euro        NaN  Monthly
# 26           CHF\tSwiss franc    80000.0   Yearly
# 27        GBP\tPound sterling    53000.0   Yearly
# 28        GBP\tPound sterling        NaN      NaN
# 29         RUB\tRussian ruble   200000.0  Monthly
# 30                        NaN        NaN      NaN
# 31    ILS\tIsraeli new shekel    35000.0  Monthly
# 32                        NaN        NaN      NaN
# 33          TRY\tTurkish lira     6000.0  Monthly
# 34  USD\tUnited States dollar     2000.0  Monthly
# 35          EUR European Euro    56000.0   Yearly
# 36  USD\tUnited States dollar   103000.0   Yearly
# 37  USD\tUnited States dollar   300000.0   Yearly
# 38                        NaN        NaN      NaN
# 39                        NaN        NaN      NaN
#
#                                LanguageHaveWorkedWith  \
# 0       C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1                                   JavaScript;Python
# 2                            Assembly;C;Python;R;Rust
# 3                               JavaScript;TypeScript
# 4                      Bash/Shell;HTML/CSS;Python;SQL
# 5   C;C#;C++;HTML/CSS;Java;JavaScript;Node.js;Powe...
# 6                                 HTML/CSS;JavaScript
# 7         HTML/CSS;JavaScript;PHP;Ruby;SQL;TypeScript
# 8                                 HTML/CSS;JavaScript
# 9                                          C++;Python
# 10                                      C#;TypeScript
# 11  Bash/Shell;HTML/CSS;JavaScript;Node.js;SQL;Typ...
# 12                               C;C++;Java;Perl;Ruby
# 13                      C;C++;JavaScript;Python;R;SQL
# 14                                     JavaScript;SQL
# 15                                  Bash/Shell;Python
# 16                C#;HTML/CSS;Java;JavaScript;Node.js
# 17        Bash/Shell;HTML/CSS;JavaScript;PHP;Ruby;SQL
# 18                                         C++;Python
# 19  C;C++;HTML/CSS;JavaScript;Matlab;Node.js;PHP;P...
# 20                                        Java;Python
# 21                                  JavaScript;Python
# 22                                 C#;HTML/CSS;Python
# 23                                  JavaScript;Python
# 24  C++;HTML/CSS;Java;JavaScript;Kotlin;Node.js;Ty...
# 25                        HTML/CSS;Julia;Python;R;SQL
# 26                                         C++;Python
# 27                                             Python
# 28       Bash/Shell;Haskell;JavaScript;SQL;TypeScript
# 29                                    Delphi;Java;SQL
# 30      HTML/CSS;JavaScript;Node.js;Python;TypeScript
# 31        Bash/Shell;Go;Java;Node.js;Python;Scala;SQL
# 32                    C++;HTML/CSS;JavaScript;PHP;SQL
# 33  Assembly;C;C#;C++;HTML/CSS;Java;JavaScript;Mat...
# 34                           Bash/Shell;C;C#;C++;Java
# 35                                  C;C++;Java;Python
# 36                        Assembly;C;Java;Kotlin;Rust
# 37                                                 Go
# 38  Bash/Shell;C#;Dart;HTML/CSS;JavaScript;TypeScript
# 39        C;C#;C++;HTML/CSS;JavaScript;Node.js;Python
#
#                                LanguageWantToWorkWith  \
# 0                                               Swift
# 1                                                 NaN
# 2                                   Julia;Python;Rust
# 3                               JavaScript;TypeScript
# 4                      Bash/Shell;HTML/CSS;Python;SQL
# 5   C#;C++;Go;HTML/CSS;Java;JavaScript;Node.js;Obj...
# 6                             HTML/CSS;JavaScript;PHP
# 7                                                Ruby
# 8                                 HTML/CSS;JavaScript
# 9                                      Haskell;Python
# 10                                                 C#
# 11  C++;Clojure;JavaScript;Node.js;Rust;SQL;TypeSc...
# 12                                               Rust
# 13                                                NaN
# 14                                 JavaScript;PHP;SQL
# 15                                  Bash/Shell;Python
# 16                         C#;Java;JavaScript;Node.js
# 17        Bash/Shell;HTML/CSS;JavaScript;PHP;Ruby;SQL
# 18                                         C++;Python
# 19  C;C++;HTML/CSS;JavaScript;Node.js;Python;SQL;T...
# 20                                        Java;Python
# 21                                         APL;Python
# 22                                 Java;Kotlin;Python
# 23                                         Python;SQL
# 24  HTML/CSS;Java;JavaScript;Kotlin;Node.js;TypeSc...
# 25                        HTML/CSS;Julia;Python;R;SQL
# 26                                 C++;Go;Java;Python
# 27                              Bash/Shell;Python;SQL
# 28                Bash/Shell;C#;F#;Haskell;Rust;Scala
# 29                              Java;Kotlin;Scala;SQL
# 30                                                NaN
# 31                   Bash/Shell;Java;Python;Scala;SQL
# 32         C++;HTML/CSS;JavaScript;PHP;SQL;TypeScript
# 33                                        C#;C++;Java
# 34                                                C++
# 35                                       C;C++;Python
# 36                           Assembly;Kotlin;Rust;SQL
# 37                                            Go;Rust
# 38                     HTML/CSS;JavaScript;TypeScript
# 39                                                NaN
#
#                      DatabaseHaveWorkedWith  \
# 0                         PostgreSQL;SQLite
# 1                                PostgreSQL
# 2                                    SQLite
# 3                                       NaN
# 4            Elasticsearch;PostgreSQL;Redis
# 5                   MySQL;PostgreSQL;SQLite
# 6                                       NaN
# 7                   MySQL;PostgreSQL;SQLite
# 8                                PostgreSQL
# 9                                PostgreSQL
# 10              Microsoft SQL Server;Oracle
# 11                               PostgreSQL
# 12                                      NaN
# 13                         MySQL;PostgreSQL
# 14                                    MySQL
# 15                                      NaN
# 16  Microsoft SQL Server;MongoDB;PostgreSQL
# 17                         MySQL;PostgreSQL
# 18                                      NaN
# 19                            MariaDB;MySQL
# 20                         MySQL;PostgreSQL
# 21                                   SQLite
# 22                                      NaN
# 23                                    MySQL
# 24                      DynamoDB;PostgreSQL
# 25                        PostgreSQL;SQLite
# 26                                      NaN
# 27                               PostgreSQL
# 28                     Microsoft SQL Server
# 29                               PostgreSQL
# 30                      MongoDB;MySQL;Redis
# 31        DynamoDB;MongoDB;MySQL;PostgreSQL
# 32               Microsoft SQL Server;MySQL
# 33                                      NaN
# 34                                      NaN
# 35                                      NaN
# 36                                      NaN
# 37                                      NaN
# 38                                   SQLite
# 39                                  MongoDB
#
#                                DatabaseWantToWorkWith  \
# 0                                              SQLite
# 1                                                 NaN
# 2                                              SQLite
# 3                                                 NaN
# 4            Cassandra;Elasticsearch;PostgreSQL;Redis
# 5   Elasticsearch;Firebase;IBM DB2;MariaDB;Microso...
# 6                                                 NaN
# 7                                          PostgreSQL
# 8                                          PostgreSQL
# 9                                                 NaN
# 10                                Elasticsearch;MySQL
# 11                           MongoDB;PostgreSQL;Redis
# 12                                                NaN
# 13                                                NaN
# 14                                              MySQL
# 15                                                NaN
# 16                                 MongoDB;PostgreSQL
# 17                                              MySQL
# 18                                                NaN
# 19                                      MariaDB;MySQL
# 20                                   MySQL;PostgreSQL
# 21                                                NaN
# 22                                                NaN
# 23             Elasticsearch;MongoDB;MySQL;PostgreSQL
# 24                                         PostgreSQL
# 25                                         PostgreSQL
# 26                                                NaN
# 27                                         PostgreSQL
# 28                                   PostgreSQL;Redis
# 29                 Cassandra;MongoDB;PostgreSQL;Redis
# 30                                            MariaDB
# 31           Cassandra;MongoDB;MySQL;PostgreSQL;Redis
# 32                         Microsoft SQL Server;MySQL
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
#
#                        PlatformHaveWorkedWith     PlatformWantToWorkWith  \
# 0                                         NaN                        NaN
# 1                                         NaN                        NaN
# 2                                      Heroku                        NaN
# 3                                         NaN                        NaN
# 4                                         NaN                        NaN
# 5                                         NaN                        NaN
# 6                                         NaN                        NaN
# 7                      Heroku;Microsoft Azure                     Heroku
# 8                                         AWS                        NaN
# 9                                         NaN                        NaN
# 10                            Microsoft Azure        AWS;Microsoft Azure
# 11                                        AWS                        NaN
# 12                                        NaN                        NaN
# 13                                        AWS               DigitalOcean
# 14                                        NaN                        NaN
# 15                                        NaN                        NaN
# 16                  AWS;Google Cloud Platform  AWS;Google Cloud Platform
# 17                                        AWS                        NaN
# 18                                        NaN                        NaN
# 19                                        NaN                        NaN
# 20                                        AWS                        NaN
# 21                                     Heroku                        NaN
# 22                                        NaN                        NaN
# 23                                        NaN                        NaN
# 24                                 AWS;Heroku                 AWS;Heroku
# 25                                        NaN                        NaN
# 26                                        NaN                        NaN
# 27                                        NaN                        NaN
# 28  AWS;Google Cloud Platform;Microsoft Azure  AWS;Google Cloud Platform
# 29                                        NaN                        NaN
# 30                    AWS;DigitalOcean;Heroku                        NaN
# 31  AWS;Google Cloud Platform;Microsoft Azure  AWS;Google Cloud Platform
# 32                                        NaN                        NaN
# 33                                        NaN                        NaN
# 34                                        NaN                        NaN
# 35                                        NaN                        NaN
# 36                                        NaN                        NaN
# 37  AWS;Google Cloud Platform;Microsoft Azure                        NaN
# 38                                     Heroku                        NaN
# 39                                     Heroku                        NaN
#
#                    WebframeHaveWorkedWith         WebframeWantToWorkWith  \
# 0                         Laravel;Symfony                            NaN
# 1                    Angular;Flask;Vue.js                            NaN
# 2                                   Flask                          Flask
# 3                          Angular;jQuery                 Angular;jQuery
# 4                                   Flask                          Flask
# 5           Express;Flask;jQuery;React.js  Express;Flask;jQuery;React.js
# 6                                  jQuery                         jQuery
# 7         Angular.js;jQuery;Ruby on Rails                  Ruby on Rails
# 8                          Django;FastAPI                 Django;FastAPI
# 9                                     NaN                            NaN
# 10                  Angular;ASP.NET Core                   ASP.NET Core
# 11                Express;React.js;Vue.js                 Express;Vue.js
# 12                          Ruby on Rails                            NaN
# 13                                  Flask                         Vue.js
# 14                                 Vue.js                         Vue.js
# 15                                    NaN                            NaN
# 16           Angular;ASP.NET Core ;Spring   Angular;ASP.NET Core ;Spring
# 17           jQuery;Laravel;Ruby on Rails   jQuery;Laravel;Ruby on Rails
# 18                                    NaN                            NaN
# 19  Angular;Express;Flask;React.js;Svelte         Express;Flask;React.js
# 20                                 Spring                         Spring
# 21                                  Flask                        FastAPI
# 22                                    NaN                            NaN
# 23                                    NaN                            NaN
# 24                 Angular;Express;Spring         Angular;Express;Spring
# 25                          Django;jQuery                            NaN
# 26                                    NaN                            NaN
# 27                                    NaN                            NaN
# 28                                    NaN                            NaN
# 29                                    NaN                            NaN
# 30         Express;React.js;Svelte;Vue.js               Express;React.js
# 31                                    NaN                            NaN
# 32              Angular.js;jQuery;Laravel         Angular;jQuery;Laravel
# 33                                 jQuery                            NaN
# 34                                    NaN                            NaN
# 35                                    NaN                            NaN
# 36                                    NaN                            NaN
# 37                                    NaN                            NaN
# 38                               React.js                React.js;Vue.js
# 39                Express;jQuery;React.js                            NaN
#
#                                MiscTechHaveWorkedWith  \
# 0                                                 NaN
# 1                                             Cordova
# 2               NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                                 NaN
# 4                    Apache Spark;Hadoop;NumPy;Pandas
# 5         Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9         Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 10                                 .NET Core / .NET 5
# 11                                                NaN
# 12                                                 Qt
# 13                     Apache Spark;Pandas;TensorFlow
# 14                                                NaN
# 15                                                NaN
# 16                         .NET Core / .NET 5;Flutter
# 17                                                NaN
# 18                         NumPy;Pandas;Torch/PyTorch
# 19                                              NumPy
# 20                                       NumPy;Pandas
# 21             .NET Core / .NET 5;NumPy;Torch/PyTorch
# 22                                                NaN
# 23  Apache Spark;Keras;NumPy;Pandas;TensorFlow;Tor...
# 24                                                NaN
# 25                            NumPy;Pandas;TensorFlow
# 26                                       NumPy;Pandas
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                          Apache Spark;NumPy;Pandas
# 32                                                 Qt
# 33               .NET Framework;.NET Core / .NET 5;Qt
# 34                                  .NET Framework;Qt
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                            Flutter
# 39                             Keras;NumPy;TensorFlow
#
#                                MiscTechWantToWorkWith  \
# 0                                                 NaN
# 1                                                 NaN
# 2         Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                                 NaN
# 4                                 Hadoop;NumPy;Pandas
# 5   Keras;NumPy;Pandas;Qt;React Native;TensorFlow;...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                Keras;NumPy;TensorFlow;Torch/PyTorch
# 10                                 .NET Core / .NET 5
# 11                                                NaN
# 12                                   NumPy;TensorFlow
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                 .NET Core / .NET 5
# 17                                                NaN
# 18                         NumPy;Pandas;Torch/PyTorch
# 19                   NumPy;Qt;React Native;TensorFlow
# 20                                       NumPy;Pandas
# 21                         NumPy;Pandas;Torch/PyTorch
# 22                                                NaN
# 23  Apache Spark;Keras;NumPy;Pandas;TensorFlow;Tor...
# 24                                                NaN
# 25                            NumPy;Pandas;TensorFlow
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                       Apache Spark
# 32                                                 Qt
# 33               .NET Framework;.NET Core / .NET 5;Qt
# 34                                                 Qt
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
#
#             ToolsTechHaveWorkedWith            ToolsTechWantToWorkWith  \
# 0                               NaN                                NaN
# 1                   Docker;Git;Yarn                                Git
# 2                               NaN                                NaN
# 3                               NaN                                NaN
# 4        Docker;Git;Kubernetes;Yarn         Docker;Git;Kubernetes;Yarn
# 5                               Git  Docker;Git;Unity 3D;Unreal Engine
# 6                               NaN                                NaN
# 7                               NaN                                NaN
# 8                        Docker;Git              Docker;Git;Kubernetes
# 9                               Git                                Git
# 10                              Git                         Docker;Git
# 11                              Git                                Git
# 12                              Git                  Docker;Kubernetes
# 13                       Docker;Git                                NaN
# 14                       Docker;Git              Docker;Git;Kubernetes
# 15                              Git                                Git
# 16                   Git;Kubernetes                     Git;Kubernetes
# 17                              Git                                Git
# 18                              NaN                                NaN
# 19                              Git                                Git
# 20                              Git                                Git
# 21                              Git                                Git
# 22                         Unity 3D                                NaN
# 23                       Docker;Git              Docker;Git;Kubernetes
# 24            Docker;Git;Kubernetes              Docker;Git;Kubernetes
# 25                       Docker;Git                                Git
# 26                       Docker;Git                         Docker;Git
# 27                              Git                                Git
# 28                              Git                         Docker;Git
# 29                       Docker;Git                         Docker;Git
# 30                  Docker;Git;Yarn                         Docker;Git
# 31  Docker;Git;Kubernetes;Terraform              Docker;Git;Kubernetes
# 32                         Git;Yarn                           Git;Yarn
# 33                     Git;Unity 3D         Git;Unity 3D;Unreal Engine
# 34                              Git                                NaN
# 35                              Git                                Git
# 36                       Docker;Git                                Git
# 37             Docker;Git;Terraform                      Git;Terraform
# 38                         Git;Yarn                                Git
# 39                    Flow;Unity 3D                                NaN
#
#                          NEWCollabToolsHaveWorkedWith  \
# 0                                      PHPStorm;Xcode
# 1           Android Studio;IntelliJ;Notepad++;PyCharm
# 2   IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 3                                                 NaN
# 4          Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
# 5   IPython/Jupyter;Notepad++;PyCharm;Sublime Text...
# 6                                                 NaN
# 7                     Sublime Text;Visual Studio Code
# 8                                PyCharm;Sublime Text
# 9              IPython/Jupyter;Vim;Visual Studio Code
# 10                            Notepad++;Visual Studio
# 11                                               Atom
# 12                                                Vim
# 13                                       Atom;RStudio
# 14                                  Eclipse;Notepad++
# 15                                   Emacs;Neovim;Vim
# 16  Android Studio;IntelliJ;Rider;Visual Studio;Vi...
# 17                    Sublime Text;Visual Studio Code
# 18                                IPython/Jupyter;Vim
# 19               Vim;Visual Studio;Visual Studio Code
# 20                                   IntelliJ;PyCharm
# 21                             Vim;Visual Studio Code
# 22                                     Android Studio
# 23                                 Visual Studio Code
# 24         Android Studio;IntelliJ;Visual Studio Code
# 25                                   Atom;RStudio;Vim
# 26                           IntelliJ;IPython/Jupyter
# 27                                         Neovim;Vim
# 28                                 Visual Studio Code
# 29                         IntelliJ;NetBeans;Webstorm
# 30                            Atom;Visual Studio Code
# 31  Atom;IntelliJ;IPython/Jupyter;PyCharm;Sublime ...
# 32                                 NetBeans;Notepad++
# 33  Atom;Eclipse;IPython/Jupyter;Notepad++;Visual ...
# 34  Android Studio;Visual Studio;Visual Studio Cod...
# 35                                           IntelliJ
# 36                          IntelliJ;PyCharm;Webstorm
# 37                             Vim;Visual Studio Code
# 38  Android Studio;IntelliJ;NetBeans;Visual Studio...
# 39    IPython/Jupyter;Sublime Text;Visual Studio Code
#
#                          NEWCollabToolsWantToWorkWith        OpSys  \
# 0                                          Atom;Xcode        MacOS
# 1                                                 NaN      Windows
# 2   IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 3                                                 NaN      Windows
# ...
# 36                               A few times per week    Yes, somewhat
# 37                              Daily or almost daily  Yes, definitely
# 38                               A few times per week    Yes, somewhat
# 39                    A few times per month or weekly    Yes, somewhat
#
#    NEWOtherComms                 Age  \
# 0             No     25-34 years old
# 1             No     18-24 years old
# 2            Yes     18-24 years old
# 3             No     35-44 years old
# 4             No     25-34 years old
# 5             No     18-24 years old
# 6             No   Prefer not to say
# 7            Yes     18-24 years old
# 8             No     25-34 years old
# 9             No     25-34 years old
# 10            No     25-34 years old
# 11           Yes     25-34 years old
# 12            No     25-34 years old
# 13            No   Prefer not to say
# 14            No     45-54 years old
# 15            No  Under 18 years old
# 16           Yes     25-34 years old
# 17            No     25-34 years old
# 18            No     45-54 years old
# 19           Yes     25-34 years old
# 20            No     25-34 years old
# 21            No     18-24 years old
# 22            No  Under 18 years old
# 23            No     25-34 years old
# 24            No     35-44 years old
# 25            No     35-44 years old
# 26            No     25-34 years old
# 27            No     45-54 years old
# 28           Yes     25-34 years old
# 29            No     35-44 years old
# 30            No   Prefer not to say
# 31            No     25-34 years old
# 32            No     25-34 years old
# 33            No     18-24 years old
# 34            No     25-34 years old
# 35           Yes     25-34 years old
# 36           Yes     18-24 years old
# 37            No     35-44 years old
# 38           Yes     18-24 years old
# 39           Yes     18-24 years old
#
#                                                Gender              Trans  \
# 0                                                 Man                 No
# 1                                                 Man                 No
# 2                                                 Man                 No
# 3                                                 Man                 No
# 4                                                 Man                 No
# 5                                   Prefer not to say                 No
# 6                                   Prefer not to say                 No
# 7                                               Woman                 No
# 8                                                 Man                 No
# 9                                                 Man                 No
# 10                                                Man                 No
# 11                                                Man                 No
# 12                                                Man                 No
# 13                                  Prefer not to say  Prefer not to say
# 14                                                Man                 No
# 15                                                Man                 No
# 16                                                Man                 No
# 17                                                Man                 No
# 18                                                Man                 No
# 19                                                Man                 No
# 20                                                Man                 No
# 21                                                Man                 No
# 22                                                Man                 No
# 23                                                Man                 No
# 24                                                Man                 No
# 25  Non-binary, genderqueer, or gender non-conforming  Prefer not to say
# 26                                                Man                 No
# 27                                                Man                 No
# 28                                                Man                 No
# 29                                                Man                 No
# 30                                                Man                 No
# 31                                                Man                 No
# 32                                                Man                 No
# 33                                                Man                 No
# 34                                                Man                 No
# 35                                                Man                 No
# 36                                                Man                 No
# 37                                                Man                 No
# 38                                                Man                 No
# 39                                              Woman                 No
#
#                            Sexuality  \
# 0            Straight / Heterosexual
# 1            Straight / Heterosexual
# 2                  Prefer not to say
# 3            Straight / Heterosexual
# 4                                NaN
# 5            Straight / Heterosexual
# 6                                NaN
# 7            Straight / Heterosexual
# 8                                NaN
# 9            Straight / Heterosexual
# 10           Straight / Heterosexual
# 11           Straight / Heterosexual
# 12           Straight / Heterosexual
# 13                 Prefer not to say
# 14                 Prefer not to say
# 15           Straight / Heterosexual
# 16                               NaN
# 17           Straight / Heterosexual
# 18           Straight / Heterosexual
# 19           Straight / Heterosexual
# 20                               NaN
# 21                               NaN
# 22                 Prefer not to say
# 23                               NaN
# 24           Straight / Heterosexual
# 25                          Bisexual
# 26                               NaN
# 27           Straight / Heterosexual
# 28           Straight / Heterosexual
# 29           Straight / Heterosexual
# 30  Straight / Heterosexual;Bisexual
# 31           Straight / Heterosexual
# 32           Straight / Heterosexual
# 33           Straight / Heterosexual
# 34           Straight / Heterosexual
# 35           Straight / Heterosexual
# 36           Straight / Heterosexual
# 37           Straight / Heterosexual
# 38           Straight / Heterosexual
# 39           Straight / Heterosexual
#
#                                             Ethnicity  \
# 0                        White or of European descent
# 1                        White or of European descent
# 2                                   Prefer not to say
# 3                        White or of European descent
# 4                        White or of European descent
# 5                                   Prefer not to say
# 6                                        I don't know
# 7   White or of European descent;Multiracial;South...
# 8                                         South Asian
# 9                        White or of European descent
# 10                       White or of European descent
# 11  White or of European descent;Hispanic or Latin...
# 12                       White or of European descent
# 13                                  Prefer not to say
# 14                                  Prefer not to say
# 15                       White or of European descent
# 16                                     Middle Eastern
# 17                       White or of European descent
# 18                       White or of European descent
# 19                                        Multiracial
# 20                       White or of European descent
# 21          White or of European descent;I don't know
# 22                                  Prefer not to say
# 23                       White or of European descent
# 24                       White or of European descent
# 25                       White or of European descent
# 26                       White or of European descent
# 27                       White or of European descent
# 28                       White or of European descent
# 29                       White or of European descent
# 30                                       I don't know
# 31        White or of European descent;Middle Eastern
# 32                       White or of European descent
# 33                       White or of European descent
# 34                       White or of European descent
# 35                       White or of European descent
# 36                       White or of European descent
# 37                       White or of European descent
# 38                                    Southeast Asian
# 39                       White or of European descent
#
#                   Accessibility  \
# 0             None of the above
# 1             None of the above
# 2             None of the above
# 3   I am deaf / hard of hearing
# 4             None of the above
# 5             None of the above
# 6             None of the above
# 7             None of the above
# 8                           NaN
# 9             None of the above
# 10            None of the above
# 11            None of the above
# 12            None of the above
# 13            Prefer not to say
# 14            None of the above
# 15            None of the above
# 16                          NaN
# 17            None of the above
# 18            None of the above
# 19            None of the above
# 20                          NaN
# 21                          NaN
# 22            None of the above
# 23            None of the above
# 24            None of the above
# 25            None of the above
# 26            None of the above
# 27            None of the above
# 28            None of the above
# 29            None of the above
# 30            None of the above
# 31            None of the above
# 32            None of the above
# 33            None of the above
# 34            None of the above
# 35            None of the above
# 36            None of the above
# 37            None of the above
# 38            None of the above
# 39            None of the above
#
#                                          MentalHealth           SurveyLength  \
# 0                                   None of the above  Appropriate in length
# 1                                   None of the above  Appropriate in length
# 2                                   None of the above  Appropriate in length
# 3                                                 NaN  Appropriate in length
# 4                                                 NaN  Appropriate in length
# 5   I have a concentration and/or memory disorder ...               Too long
# 6                                   None of the above  Appropriate in length
# 7                                   None of the above  Appropriate in length
# 8   I have a concentration and/or memory disorder ...  Appropriate in length
# 9                                   None of the above  Appropriate in length
# 10                                  None of the above  Appropriate in length
# 11                                  None of the above               Too long
# 12                                  Prefer not to say  Appropriate in length
# 13                                  Prefer not to say               Too long
# 14  I have a mood or emotional disorder (e.g. depr...  Appropriate in length
# 15  I have a concentration and/or memory disorder ...               Too long
# 16                                                NaN  Appropriate in length
# 17                                  None of the above  Appropriate in length
# 18                                  None of the above  Appropriate in length
# 19                                  None of the above  Appropriate in length
# 20                                                NaN               Too long
# 21                                  None of the above                    NaN
# 22                                  None of the above  Appropriate in length
# 23                                  None of the above  Appropriate in length
# 24                                  None of the above  Appropriate in length
# 25                         I have an anxiety disorder  Appropriate in length
# 26                                  None of the above  Appropriate in length
# 27                                  None of the above  Appropriate in length
# 28  I have a concentration and/or memory disorder ...  Appropriate in length
# 29                                  None of the above  Appropriate in length
# 30  I have a concentration and/or memory disorder ...  Appropriate in length
# 31  I have a concentration and/or memory disorder ...  Appropriate in length
# 32                         I have an anxiety disorder  Appropriate in length
# 33  I have a concentration and/or memory disorder ...  Appropriate in length
# 34                                                NaN  Appropriate in length
# 35                                  None of the above  Appropriate in length
# 36                                  Prefer not to say              Too short
# 37  I have a concentration and/or memory disorder ...  Appropriate in length
# 38  I have a concentration and/or memory disorder ...  Appropriate in length
# 39  I have a concentration and/or memory disorder ...  Appropriate in length
#
#                     SurveyEase  ConvertedCompYearly
# 0                         Easy              62268.0
# 1                         Easy                  NaN
# 2                         Easy                  NaN
# 3   Neither easy nor difficult                  NaN
# 4                         Easy                  NaN
# 5   Neither easy nor difficult                  NaN
# 6   Neither easy nor difficult                  NaN
# 7                         Easy                  NaN
# 8                         Easy                  NaN
# 9   Neither easy nor difficult              51552.0
# 10                        Easy                  NaN
# 11                        Easy              46482.0
# 12                        Easy              77290.0
# 13  Neither easy nor difficult                  NaN
# 14  Neither easy nor difficult                  NaN
# 15                        Easy                  NaN
# 16  Neither easy nor difficult              17748.0
# 17                        Easy              46135.0
# 18                        Easy             160932.0
# 19                        Easy                  NaN
# 20                        Easy                  NaN
# 21                         NaN                  NaN
# 22                        Easy                  NaN
# 23  Neither easy nor difficult              38915.0
# 24                        Easy              77831.0
# 25  Neither easy nor difficult                  NaN
# 26                        Easy              81319.0
# 27                        Easy              68507.0
# 28                        Easy                  NaN
# 29  Neither easy nor difficult              37752.0
# 30                        Easy                  NaN
# 31                        Easy             122580.0
# 32                        Easy                  NaN
# 33                        Easy              11832.0
# 34                        Easy              24000.0
# 35                        Easy              60535.0
# 36                        Easy             103000.0
# 37                        Easy             300000.0
# 38  Neither easy nor difficult                  NaN
# 39                        Easy                  NaN

# %%
df.loc[0]
# Out:
# ResponseId                                                                      1
# MainBranch                                         I am a developer by profession
# Employment                      Independent contractor, freelancer, or self-em...
# Country                                                                  Slovakia
# US_State                                                                      NaN
# UK_Country                                                                    NaN
# EdLevel                         Secondary school (e.g. American high school, G...
# Age1stCode                                                          18 - 24 years
# LearnCode                       Coding Bootcamp;Other online resources (ex: vi...
# YearsCode                                                                     NaN
# YearsCodePro                                                                  NaN
# DevType                                                         Developer, mobile
# OrgSize                                                        20 to 99 employees
# Currency                                                        EUR European Euro
# CompTotal                                                                  4800.0
# CompFreq                                                                  Monthly
# LanguageHaveWorkedWith              C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# LanguageWantToWorkWith                                                      Swift
# DatabaseHaveWorkedWith                                          PostgreSQL;SQLite
# DatabaseWantToWorkWith                                                     SQLite
# PlatformHaveWorkedWith                                                        NaN
# PlatformWantToWorkWith                                                        NaN
# WebframeHaveWorkedWith                                            Laravel;Symfony
# WebframeWantToWorkWith                                                        NaN
# MiscTechHaveWorkedWith                                                        NaN
# MiscTechWantToWorkWith                                                        NaN
# ToolsTechHaveWorkedWith                                                       NaN
# ToolsTechWantToWorkWith                                                       NaN
# NEWCollabToolsHaveWorkedWith                                       PHPStorm;Xcode
# NEWCollabToolsWantToWorkWith                                           Atom;Xcode
# OpSys                                                                       MacOS
# NEWStuck                        Call a coworker or friend;Visit Stack Overflow...
# NEWSOSites                                                         Stack Overflow
# SOVisitFreq                                                Multiple times per day
# SOAccount                                                                     Yes
# SOPartFreq                                        A few times per month or weekly
# SOComm                                                            Yes, definitely
# NEWOtherComms                                                                  No
# Age                                                               25-34 years old
# Gender                                                                        Man
# Trans                                                                          No
# Sexuality                                                 Straight / Heterosexual
# Ethnicity                                            White or of European descent
# Accessibility                                                   None of the above
# MentalHealth                                                    None of the above
# SurveyLength                                                Appropriate in length
# SurveyEase                                                                   Easy
# ConvertedCompYearly                                                       62268.0
# Name: 0, dtype: object

# %%
df.shape
# Out:
# (83439, 48)

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
df['Employment']
# Out:
# 0        Independent contractor, freelancer, or self-em...
# 1                                       Student, full-time
# 2                                       Student, full-time
# 3                                       Employed full-time
# 4        Independent contractor, freelancer, or self-em...
#                                ...
# 83434                                   Employed full-time
# 83435    Independent contractor, freelancer, or self-em...
# 83436                                   Employed full-time
# 83437                                   Employed full-time
# 83438                                   Employed full-time
# Name: Employment, Length: 83439, dtype: object

# %%
df['Employment'].value_counts()
# Out:
# Employed full-time                                      53584
# Student, full-time                                      11781
# Independent contractor, freelancer, or self-employed     8041
# Not employed, but looking for work                       2961
# Employed part-time                                       2461
# Student, part-time                                       2051
# Not employed, and not looking for work                   1228
# I prefer not to say                                       890
# Retired                                                   326
# Name: Employment, dtype: int64

# %%
df.loc[0]
# Out:
# ResponseId                                                                      1
# MainBranch                                         I am a developer by profession
# Employment                      Independent contractor, freelancer, or self-em...
# Country                                                                  Slovakia
# US_State                                                                      NaN
# UK_Country                                                                    NaN
# EdLevel                         Secondary school (e.g. American high school, G...
# Age1stCode                                                          18 - 24 years
# LearnCode                       Coding Bootcamp;Other online resources (ex: vi...
# YearsCode                                                                     NaN
# YearsCodePro                                                                  NaN
# DevType                                                         Developer, mobile
# OrgSize                                                        20 to 99 employees
# Currency                                                        EUR European Euro
# CompTotal                                                                  4800.0
# CompFreq                                                                  Monthly
# LanguageHaveWorkedWith              C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# LanguageWantToWorkWith                                                      Swift
# DatabaseHaveWorkedWith                                          PostgreSQL;SQLite
# DatabaseWantToWorkWith                                                     SQLite
# PlatformHaveWorkedWith                                                        NaN
# PlatformWantToWorkWith                                                        NaN
# WebframeHaveWorkedWith                                            Laravel;Symfony
# WebframeWantToWorkWith                                                        NaN
# MiscTechHaveWorkedWith                                                        NaN
# MiscTechWantToWorkWith                                                        NaN
# ToolsTechHaveWorkedWith                                                       NaN
# ToolsTechWantToWorkWith                                                       NaN
# NEWCollabToolsHaveWorkedWith                                       PHPStorm;Xcode
# NEWCollabToolsWantToWorkWith                                           Atom;Xcode
# OpSys                                                                       MacOS
# NEWStuck                        Call a coworker or friend;Visit Stack Overflow...
# NEWSOSites                                                         Stack Overflow
# SOVisitFreq                                                Multiple times per day
# SOAccount                                                                     Yes
# SOPartFreq                                        A few times per month or weekly
# SOComm                                                            Yes, definitely
# NEWOtherComms                                                                  No
# Age                                                               25-34 years old
# Gender                                                                        Man
# Trans                                                                          No
# Sexuality                                                 Straight / Heterosexual
# Ethnicity                                            White or of European descent
# Accessibility                                                   None of the above
# MentalHealth                                                    None of the above
# SurveyLength                                                Appropriate in length
# SurveyEase                                                                   Easy
# ConvertedCompYearly                                                       62268.0
# Name: 0, dtype: object

# %%
df.loc[0, 'Employment']
# Out:
# 'Independent contractor, freelancer, or self-employed'

# %%
df.loc[83438, 'Employment']
# Out:
# 'Employed full-time'

# %%
df.loc[[0,1,2,3], 'Employment']
# Out:
# 0    Independent contractor, freelancer, or self-em...
# 1                                   Student, full-time
# 2                                   Student, full-time
# 3                                   Employed full-time
# Name: Employment, dtype: object

# %%
df.loc[0:3, 'Employment']
# Out:
# 0    Independent contractor, freelancer, or self-em...
# 1                                   Student, full-time
# 2                                   Student, full-time
# 3                                   Employed full-time
# Name: Employment, dtype: object

# %%
df.loc[[0,1,2,3], 'Employment':'Age1stCode']
# Out:
#                                           Employment             Country  \
# 0  Independent contractor, freelancer, or self-em...            Slovakia
# 1                                 Student, full-time         Netherlands
# 2                                 Student, full-time  Russian Federation
# 3                                 Employed full-time             Austria
#
#   US_State UK_Country                                            EdLevel  \
# 0      NaN        NaN  Secondary school (e.g. American high school, G...
# 1      NaN        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2      NaN        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3      NaN        NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#       Age1stCode
# 0  18 - 24 years
# 1  11 - 17 years
# 2  11 - 17 years
# 3  11 - 17 years
