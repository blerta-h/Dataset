# %%
import numpy as np
import matplotlib.mlab as mlab
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = [21,22,23,4,5,6,77,8,9,10,31,32,33,34,35,36,37,18,49,50,100]

# %%
num_bins = 5
plt.hist(data, num_bins, facecolor='blue', alpha=0.7, edgecolor='red');

# %%
num_bins = 3
plt.hist(data, num_bins, facecolor='green', alpha=0.7, edgecolor='purple');

# %%
plt.plot(data)
plt.show()

# %%
import numpy as np
np.linspace(0, 1, 5)
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
import numpy as np
x = np.random.randint(10, size=10)
x
# Out:
# array([8, 1, 2, 4, 0, 9, 7, 2, 8, 7])

# %%
plt.plot(x)
plt.show()

# %%
import numpy as np
x2 = np.sort(x)
x2
# Out:
# array([0, 1, 2, 2, 4, 7, 7, 8, 8, 9])

# %%
plt.plot(x2)
plt.show()

# %%
x = [37, 18, 49, 50, 100, 21, 32, 37, 18, 49, 50, 100, 22, 23, 6, 5, 4, 77, 8, 9, 10, 31]

# %%
x[::-1]
# Out:
# [31,
#  10,
#  9,
#  8,
#  77,
#  4,
#  5,
#  6,
#  23,
#  22,
#  100,
#  50,
#  49,
#  18,
#  37,
#  32,
#  21,
#  100,
#  50,
#  49,
#  18,
#  37]

# %%
plt.plot(x)
plt.show()

# %%
import pandas as pd
data = pd.read_csv('BP.csv')
print(data)
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2019-01-02  37.470001  38.740002  37.410000  38.590000  32.781559
# 1    2019-01-03  38.959999  39.060001  38.480000  38.810001  32.968441
# 2    2019-01-04  39.570000  40.080002  39.419998  40.029999  34.004814
# 3    2019-01-07  39.700001  40.310001  39.580002  40.160000  34.115242
# 4    2019-01-08  40.180000  40.259998  39.830002  40.029999  34.004814
# ..          ...        ...        ...        ...        ...        ...
# 602  2021-05-24  26.690001  27.080000  26.500000  27.020000  27.020000
# 603  2021-05-25  26.860001  26.900000  26.240000  26.280001  26.280001
# 604  2021-05-26  26.320000  26.459999  26.200001  26.309999  26.309999
# 605  2021-05-27  26.040001  26.290001  26.020000  26.280001  26.280001
# 606  2021-05-28  26.129999  26.340000  26.070000  26.230000  26.230000
#
#        Volume
# 0     5537100
# 1     7137300
# 2     9336700
# 3     6114300
# 4     5654900
# ..        ...
# ...

# %%
df = pd.read_csv("BP.csv")

# %%
df
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2019-01-02  37.470001  38.740002  37.410000  38.590000  32.781559
# 1    2019-01-03  38.959999  39.060001  38.480000  38.810001  32.968441
# 2    2019-01-04  39.570000  40.080002  39.419998  40.029999  34.004814
# 3    2019-01-07  39.700001  40.310001  39.580002  40.160000  34.115242
# 4    2019-01-08  40.180000  40.259998  39.830002  40.029999  34.004814
# ..          ...        ...        ...        ...        ...        ...
# 602  2021-05-24  26.690001  27.080000  26.500000  27.020000  27.020000
# 603  2021-05-25  26.860001  26.900000  26.240000  26.280001  26.280001
# 604  2021-05-26  26.320000  26.459999  26.200001  26.309999  26.309999
# 605  2021-05-27  26.040001  26.290001  26.020000  26.280001  26.280001
# 606  2021-05-28  26.129999  26.340000  26.070000  26.230000  26.230000
#
#        Volume
# 0     5537100
# 1     7137300
# 2     9336700
# 3     6114300
# 4     5654900
# ..        ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       607 non-null    object
#  1   Open       607 non-null    float64
#  2   High       607 non-null    float64
#  3   Low        607 non-null    float64
#  4   Close      607 non-null    float64
#  5   Adj Close  607 non-null    float64
#  6   Volume     607 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 33.3+ KB

# %%
pd.set_option('display.max_columns',20)
pd.set_option('display.max_rows', 20)

# %%
df
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2019-01-02  37.470001  38.740002  37.410000  38.590000  32.781559
# 1    2019-01-03  38.959999  39.060001  38.480000  38.810001  32.968441
# 2    2019-01-04  39.570000  40.080002  39.419998  40.029999  34.004814
# 3    2019-01-07  39.700001  40.310001  39.580002  40.160000  34.115242
# 4    2019-01-08  40.180000  40.259998  39.830002  40.029999  34.004814
# ..          ...        ...        ...        ...        ...        ...
# 602  2021-05-24  26.690001  27.080000  26.500000  27.020000  27.020000
# 603  2021-05-25  26.860001  26.900000  26.240000  26.280001  26.280001
# 604  2021-05-26  26.320000  26.459999  26.200001  26.309999  26.309999
# 605  2021-05-27  26.040001  26.290001  26.020000  26.280001  26.280001
# 606  2021-05-28  26.129999  26.340000  26.070000  26.230000  26.230000
#
#        Volume
# 0     5537100
# 1     7137300
# 2     9336700
# 3     6114300
# 4     5654900
# ..        ...
# ...

# %%
df['Open']
# Out:
# 0      37.470001
# 1      38.959999
# 2      39.570000
# 3      39.700001
# 4      40.180000
#          ...
# 602    26.690001
# 603    26.860001
# 604    26.320000
# 605    26.040001
# 606    26.129999
# Name: Open, Length: 607, dtype: float64

# %%
df['High'].head(10)
# Out:
# 0    38.740002
# 1    39.060001
# 2    40.080002
# 3    40.310001
# 4    40.259998
# 5    40.610001
# 6    40.759998
# 7    40.419998
# 8    40.669998
# 9    40.650002
# Name: High, dtype: float64

# %%
df['Low'].tail(10)
# Out:
# 597    26.480000
# 598    26.730000
# 599    26.000000
# 600    26.180000
# 601    26.469999
# 602    26.500000
# 603    26.240000
# 604    26.200001
# 605    26.020000
# 606    26.070000
# Name: Low, dtype: float64

# %%
import pandas as pd
cols_to_read = ['Date', 'Adj Close']
data = pd.read_csv('BP.csv', usecols=cols_to_read)
data.head()
# Out:
#          Date  Adj Close
# 0  2019-01-02  32.781559
# 1  2019-01-03  32.968441
# 2  2019-01-04  34.004814
# 3  2019-01-07  34.115242
# 4  2019-01-08  34.004814

# %%
import pandas as pd
# read only 10 rows of data
data = pd.read_csv('BP.csv', nrows=10, sep='\t')
data
# Out:
#            Date,Open,High,Low,Close,Adj Close,Volume
# 0  2019-01-02,37.470001,38.740002,37.410000,38.59...
# 1  2019-01-03,38.959999,39.060001,38.480000,38.81...
# 2  2019-01-04,39.570000,40.080002,39.419998,40.02...
# 3  2019-01-07,39.700001,40.310001,39.580002,40.16...
# 4  2019-01-08,40.180000,40.259998,39.830002,40.02...
# 5  2019-01-09,40.389999,40.610001,40.150002,40.36...
# 6  2019-01-10,40.279999,40.759998,40.130001,40.70...
# 7  2019-01-11,40.220001,40.419998,40.070000,40.24...
# 8  2019-01-14,40.150002,40.669998,40.090000,40.41...
# 9  2019-01-15,40.259998,40.650002,39.959999,40.24...

# %%
import pandas as pd
#  Setting one column as Index
data = pd.read_csv('BP.csv', index_col=2)
data.head()
# Out:
#                  Date       Open        Low      Close  Adj Close   Volume
# High
# 38.740002  2019-01-02  37.470001  37.410000  38.590000  32.781559  5537100
# 39.060001  2019-01-03  38.959999  38.480000  38.810001  32.968441  7137300
# 40.080002  2019-01-04  39.570000  39.419998  40.029999  34.004814  9336700
# 40.310001  2019-01-07  39.700001  39.580002  40.160000  34.115242  6114300
# 40.259998  2019-01-08  40.180000  39.830002  40.029999  34.004814  5654900

# %%
import pandas as pd
import numpy as np
# only read selected columns
cols_to_read = ['Open', 'Close', 'Volume']
data = pd.read_csv('BP.csv', usecols=cols_to_read)
open_price = np.array(data['Open'])
# print(open_price)
print("Mean open_price: ", open_price.mean())
print("Standard deviation:", open_price.std())
print("Minimum open_price: ", open_price.min())
print("Maximum open_price: ", open_price.max())
print("Index of Minimum open_price: ", open_price.argmin())
print("Index of Maximum open_price::", open_price.argmax())
print("25th percentile: ", np.percentile(open_price, 25))
print("Median: ", np.median(open_price))
print("75th percentile: ", np.percentile(open_price, 75))
# Out:
# Mean open_price:  30.957347627677102
# Standard deviation: 9.012912334135581
# Minimum open_price:  14.98
# Maximum open_price:  45.200001
# Index of Minimum open_price:  461
# Index of Maximum open_price:: 76
# 25th percentile:  23.09
# Median:  26.889999
# 75th percentile:  39.2749995

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn; seaborn.set() # set plot style

data = pd.read_csv('BP.csv')
open_price = np.array(data['Open'])
plt.hist(open_price) # Histogram
plt.title('Distribution of stocks Open Prices')
plt.xlabel('Stock Prices')
plt.ylabel('Number of observations');

# %%
print("Original list ", x)
# pop(index): Removes and returns the item at the given index from the list
element = x.pop(4)
print("List After removing element at index 4 ", x)

x.insert(2, element)
# insert(index, item): Add the item at the specified position(index) in the list
print("List after Adding element at index 2 ", x)
# Out:
# Original list  [37, 18, 49, 50, 100, 21, 32, 37, 18, 49, 50, 100, 22, 23, 6, 5, 4, 77, 8, 9, 10, 31]
# List After removing element at index 4  [37, 18, 49, 50, 21, 32, 37, 18, 49, 50, 100, 22, 23, 6, 5, 4, 77, 8, 9, 10, 31]
# List after Adding element at index 2  [37, 18, 100, 49, 50, 21, 32, 37, 18, 49, 50, 100, 22, 23, 6, 5, 4, 77, 8, 9, 10, 31]

# %%
# Count the occurrence of each element from a list
x = [11, 45, 8, 11, 23, 45, 23, 45, 89]
print("Original list ", x)

# create a dictionary to show the count of each element
count_occurrence = dict()
for item in x:
    if item in count_occurrence:
        count_occurrence[item] += 1
    else:
        count_occurrence[item] = 1

print("Printing count of each item  ", count_occurrence)
# Out:
# Original list  [11, 45, 8, 11, 23, 45, 23, 45, 89]
# Printing count of each item   {11: 2, 45: 3, 8: 1, 23: 2, 89: 1}
