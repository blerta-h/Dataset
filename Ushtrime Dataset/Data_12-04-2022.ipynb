# %%
import pandas as pd

# %%
df=pd.read_csv('survey_results_public.csv')

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
df.shape
# Out:
# (83439, 48)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83439 entries, 0 to 83438
# Data columns (total 48 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ResponseId                    83439 non-null  int64
#  1   MainBranch                    83439 non-null  object
#  2   Employment                    83323 non-null  object
#  3   Country                       83439 non-null  object
#  4   US_State                      14920 non-null  object
#  5   UK_Country                    4418 non-null   object
#  6   EdLevel                       83126 non-null  object
#  7   Age1stCode                    83243 non-null  object
#  8   LearnCode                     82963 non-null  object
#  9   YearsCode                     81641 non-null  object
#  10  YearsCodePro                  61216 non-null  object
#  11  DevType                       66484 non-null  object
# ...

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
pd.set_option('display.max_columns', 50)

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
pd.set_option('display.max_rows', 50)

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# ...

# %%
df.head(10)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
# 5           6             I am a student who is learning to code
# 6           7                        I code primarily as a hobby
# 7           8             I am a student who is learning to code
# 8           9                     I am a developer by profession
# 9          10                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# ...

# %%
df.tail(10)
# Out:
#        ResponseId                      MainBranch  \
# 83429       83430     I code primarily as a hobby
# 83430       83431  I am a developer by profession
# 83431       83432  I am a developer by profession
# 83432       83433  I am a developer by profession
# 83433       83434  I am a developer by profession
# 83434       83435  I am a developer by profession
# 83435       83436  I am a developer by profession
# 83436       83437  I am a developer by profession
# 83437       83438  I am a developer by profession
# 83438       83439  I am a developer by profession
#
#                                               Employment  \
# 83429                 Not employed, but looking for work
# 83430                                 Employed full-time
# 83431  Independent contractor, freelancer, or self-em...
# 83432                                 Employed full-time
# 83433  Independent contractor, freelancer, or self-em...
# 83434                                 Employed full-time
# ...

# %%
schema_df=pd.read_csv('survey_results_schema.csv')

# %%
schema_df
# Out:
#        qid               qname  \
# 0    QID16                  S0
# 1    QID12            MetaInfo
# 2     QID1                  S1
# 3     QID2          MainBranch
# 4    QID24          Employment
# 5     QID6             Country
# 6     QID7            US_State
# 7     QID9          UK_Country
# 8   QID190                  S2
# 9    QID25             EdLevel
# 10  QID149          Age1stCode
# 11  QID276           LearnCode
# 12   QID32           YearsCode
# 13   QID34        YearsCodePro
# 14   QID31             DevType
# 15   QID29             OrgSize
# 16   QID50            Currency
# 17   QID51           CompTotal
# 18   QID52            CompFreq
# 19   QID61                  S3
# 20  QID233            Language
# 21  QID262            Database
# 22  QID263            Platform
# 23  QID264            Webframe
# 24  QID265            MiscTech
# 25  QID275           ToolsTech
# 26  QID274      NEWCollabTools
# 27   QID71               OpSys
# 28  QID243            NEWStuck
# ...

# %%
df.loc[1]
# Out:
# ResponseId                                                                      2
# MainBranch                                 I am a student who is learning to code
# Employment                                                     Student, full-time
# Country                                                               Netherlands
# US_State                                                                      NaN
# UK_Country                                                                    NaN
# EdLevel                              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# Age1stCode                                                          11 - 17 years
# LearnCode                       Other online resources (ex: videos, blogs, etc...
# YearsCode                                                                       7
# YearsCodePro                                                                  NaN
# ...

# %%
schema_df
# Out:
#        qid               qname  \
# 0    QID16                  S0
# 1    QID12            MetaInfo
# 2     QID1                  S1
# 3     QID2          MainBranch
# 4    QID24          Employment
# 5     QID6             Country
# 6     QID7            US_State
# 7     QID9          UK_Country
# 8   QID190                  S2
# 9    QID25             EdLevel
# 10  QID149          Age1stCode
# 11  QID276           LearnCode
# 12   QID32           YearsCode
# 13   QID34        YearsCodePro
# 14   QID31             DevType
# 15   QID29             OrgSize
# 16   QID50            Currency
# 17   QID51           CompTotal
# 18   QID52            CompFreq
# 19   QID61                  S3
# 20  QID233            Language
# 21  QID262            Database
# 22  QID263            Platform
# 23  QID264            Webframe
# 24  QID265            MiscTech
# 25  QID275           ToolsTech
# 26  QID274      NEWCollabTools
# 27   QID71               OpSys
# 28  QID243            NEWStuck
# ...

# %%
schema_df=pd.read_csv('survey_results_schema.csv', index_col='qname')

# %%
schema_df
# Out:
#                        qid                                           question  \
# qname
# S0                   QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo             QID12                                  Browser Meta Info
# S1                    QID1  <span style="font-size:22px; font-family: aria...
# MainBranch            QID2  Which of the following options best describes ...
# Employment           QID24  Which of the following best describes your cur...
# Country               QID6  Where do you live? <span style="font-weight: b...
# US_State              QID7  <p>In which state or territory of the USA do y...
# UK_Country            QID9  In which part of the United Kingdom do you liv...
# S2                  QID190  <span style="font-size:22px; font-family: aria...
# EdLevel              QID25  Which of the following best describes the high...
# Age1stCode          QID149  At what age did you write your first line of c...
# ...

# %%
schema_df.loc['Currency']
# Out:
# qid                                                       QID50
# question      Which currency do you use day-to-day? If your ...
# force_resp                                                 True
# type                                                         MC
# selector                                                     SB
# Name: Currency, dtype: object

# %%
schema_df.loc['Currency','question']
# Out:
# "Which currency do you use day-to-day? If your answer is complicated, please pick the one you're most comfortable estimating in. *"

# %%
schema_df.loc['Language']
# Out:
# qid                                                      QID233
# question      Which <b>programming, scripting, and markup la...
# force_resp                                                False
# type                                                     Matrix
# selector                                                 Likert
# Name: Language, dtype: object

# %%
schema_df.loc['Language', 'question']
# Out:
# 'Which <b>programming, scripting, and markup languages</b> have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the language and want to continue to do so, please check both boxes in that row.)'

# %%
schema_df.sort_index()
# Out:
#                        qid                                           question  \
# qname
# Accessibility       QID124  Which of the following describe you, if any? P...
# Age                 QID127                                  What is your age?
# Age1stCode          QID149  At what age did you write your first line of c...
# CompFreq             QID52   Is that compensation weekly, monthly, or yearly?
# CompTotal            QID51  What is your current total compensation (salar...
# Country               QID6  Where do you live? <span style="font-weight: b...
# Currency             QID50  Which currency do you use day-to-day? If your ...
# Database            QID262  Which <b>database environments </b>have you do...
# DevType              QID31  Which of the following describes your current ...
# EdLevel              QID25  Which of the following best describes the high...
# Employment           QID24  Which of the following best describes your cur...
# ...

# %%
schema_df.sort_index(ascending=False)
# Out:
#                        qid                                           question  \
# qname
# YearsCodePro         QID34  NOT including education, how many years have y...
# YearsCode            QID32  Including any education, how many years have y...
# Webframe            QID264  Which <strong>web frameworks </strong><span st...
# US_State              QID7  <p>In which state or territory of the USA do y...
# UK_Country            QID9  In which part of the United Kingdom do you liv...
# Trans               QID153                    Do you identify as transgender?
# ToolsTech           QID275  Which <strong>tools</strong> have you done ext...
# SurveyLength        QID132  How do you feel about the length of the survey...
# SurveyEase          QID133  How easy or difficult was this survey to compl...
# Sexuality           QID136  Which of the following describe you, if any? P...
# SOVisitFreq         QID100  How frequently would you say you visit Stack O...
# ...

# %%
schema_df.sort_index(inplace=True)

# %%
schema_df
# Out:
#                        qid                                           question  \
# qname
# Accessibility       QID124  Which of the following describe you, if any? P...
# Age                 QID127                                  What is your age?
# Age1stCode          QID149  At what age did you write your first line of c...
# CompFreq             QID52   Is that compensation weekly, monthly, or yearly?
# CompTotal            QID51  What is your current total compensation (salar...
# Country               QID6  Where do you live? <span style="font-weight: b...
# Currency             QID50  Which currency do you use day-to-day? If your ...
# Database            QID262  Which <b>database environments </b>have you do...
# DevType              QID31  Which of the following describes your current ...
# EdLevel              QID25  Which of the following best describes the high...
# Employment           QID24  Which of the following best describes your cur...
# ...

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# ...

# %%
high_salary=(df['ConvertedCompYearly'] > 100000)

# %%
high_salary
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 83434     True
# 83435    False
# 83436     True
# 83437     True
# 83438    False
# Name: ConvertedCompYearly, Length: 83439, dtype: bool

# %%
df.loc[high_salary]
# Out:
#        ResponseId                                         MainBranch  \
# 18             19  I am not primarily a developer, but I write co...
# 31             32                     I am a developer by profession
# 36             37                     I am a developer by profession
# 37             38                     I am a developer by profession
# 62             63  I am not primarily a developer, but I write co...
# ...           ...                                                ...
# 83424       83425                     I am a developer by profession
# 83427       83428                     I am a developer by profession
# 83430       83431                     I am a developer by profession
# 83434       83435                     I am a developer by profession
# 83437       83438                     I am a developer by profession
#
#                 Employment                   Country              US_State  \
# ...

# %%
df.loc[high_salary,['Country','LanguageHaveWorkedWith','ConvertedCompYearly']]
# Out:
#                         Country  \
# 18                    Singapore
# 31                       Israel
# 36     United States of America
# 37     United States of America
# 62     United States of America
# ...                         ...
# 83424                   Germany
# 83427  United States of America
# 83430  United States of America
# 83434  United States of America
# 83437                    Canada
#
#                                   LanguageHaveWorkedWith  ConvertedCompYearly
# 18                                            C++;Python             160932.0
# 31           Bash/Shell;Go;Java;Node.js;Python;Scala;SQL             122580.0
# 36                           Assembly;C;Java;Kotlin;Rust             103000.0
# 37                                                    Go             300000.0
# 62     C#;HTML/CSS;JavaScript;Node.js;PowerShell;Pyth...             130000.0
# ...                                                  ...                  ...
# ...

# %%
contries=['Singapore','Israel','Germany']

# %%
contries
# Out:
# ['Singapore', 'Israel', 'Germany']

# %%
filt=df['Country'].isin(contries)

# %%
df.loc[filt,'Country']
# Out:
# 12         Germany
# 18       Singapore
# 20         Germany
# 24         Germany
# 25         Germany
#            ...
# 83373    Singapore
# 83413      Germany
# 83415      Germany
# 83418       Israel
# 83424      Germany
# Name: Country, Length: 6877, dtype: object

# %%
df['LanguageHaveWorkedWith']
# Out:
# 0        C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1                                    JavaScript;Python
# 2                             Assembly;C;Python;R;Rust
# 3                                JavaScript;TypeScript
# 4                       Bash/Shell;HTML/CSS;Python;SQL
#                              ...
# 83434                               Clojure;Kotlin;SQL
# 83435                                              NaN
# 83436                               Groovy;Java;Python
# 83437             Bash/Shell;JavaScript;Node.js;Python
# 83438           Delphi;Elixir;HTML/CSS;Java;JavaScript
# Name: LanguageHaveWorkedWith, Length: 83439, dtype: object

# %%
filt=df['LanguageHaveWorkedWith'].str.contains('NaN')

# %%
df['LanguageHaveWorkedWith']
# Out:
# 0        C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1                                    JavaScript;Python
# 2                             Assembly;C;Python;R;Rust
# 3                                JavaScript;TypeScript
# 4                       Bash/Shell;HTML/CSS;Python;SQL
#                              ...
# 83434                               Clojure;Kotlin;SQL
# 83435                                              NaN
# 83436                               Groovy;Java;Python
# 83437             Bash/Shell;JavaScript;Node.js;Python
# 83438           Delphi;Elixir;HTML/CSS;Java;JavaScript
# Name: LanguageHaveWorkedWith, Length: 83439, dtype: object

# %%
filt=df['LanguageHaveWorkedWith'].str.contains('NaN',na=False)

# %%
df['LanguageHaveWorkedWith']
# Out:
# 0        C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1                                    JavaScript;Python
# 2                             Assembly;C;Python;R;Rust
# 3                                JavaScript;TypeScript
# 4                       Bash/Shell;HTML/CSS;Python;SQL
#                              ...
# 83434                               Clojure;Kotlin;SQL
# 83435                                              NaN
# 83436                               Groovy;Java;Python
# 83437             Bash/Shell;JavaScript;Node.js;Python
# 83438           Delphi;Elixir;HTML/CSS;Java;JavaScript
# Name: LanguageHaveWorkedWith, Length: 83439, dtype: object

# %%
filt
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 83434     True
# 83435    False
# 83436    False
# 83437    False
# 83438    False
# Name: LanguageHaveWorkedWith, Length: 83439, dtype: bool

# %%
df.loc[filt]
# Out:
# Empty DataFrame
# Columns: [ResponseId, MainBranch, Employment, Country, US_State, UK_Country, EdLevel, Age1stCode, LearnCode, YearsCode, YearsCodePro, DevType, OrgSize, Currency, CompTotal, CompFreq, LanguageHaveWorkedWith, LanguageWantToWorkWith, DatabaseHaveWorkedWith, DatabaseWantToWorkWith, PlatformHaveWorkedWith, PlatformWantToWorkWith, WebframeHaveWorkedWith, WebframeWantToWorkWith, MiscTechHaveWorkedWith, MiscTechWantToWorkWith, ToolsTechHaveWorkedWith, ToolsTechWantToWorkWith, NEWCollabToolsHaveWorkedWith, NEWCollabToolsWantToWorkWith, OpSys, NEWStuck, NEWSOSites, SOVisitFreq, SOAccount, SOPartFreq, SOComm, NEWOtherComms, Age, Gender, Trans, Sexuality, Ethnicity, Accessibility, MentalHealth, SurveyLength, SurveyEase, ConvertedCompYearly]
# Index: []

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
df.rename(columns={'ConvertedCompYearly': 'Funta'}, inplace=True)

# %%
df['Funta']
# Out:
# 0         62268.0
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#            ...
# 83434    160500.0
# 83435      3960.0
# 83436     90000.0
# 83437    816816.0
# 83438     21168.0
# Name: Funta, Length: 83439, dtype: float64

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
df['SOAccount'].map({'Yes': True, 'No': False})
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 83434    False
# 83435     True
# 83436     True
# 83437     True
# 83438     True
# Name: SOAccount, Length: 83439, dtype: object

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
df['SOAccount'] = df['SOAccount'].map({'Yes': True, 'No': False})

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...
