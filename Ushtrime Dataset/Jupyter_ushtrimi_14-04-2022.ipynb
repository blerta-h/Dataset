# %%
personat = {
    "emri": ["Blerta", "Agon", "Bernard", "Arbnor", "Blerta","Adnan","Adnan"],
    "mbiemri": ["Hoxha", "Salihu", "Kastrati", "Hetemi", "Ahmeti","Lupqi","Mehmeti"],
    "email": ["blerta.hoxha@gmail.com", "agon.salihu@gmail.com", "bernard.kastrati@gmail.com", "arbnor.hetemi@gmail.com","blerta.ahmeti@gmail.com","adnan.lupqi@gmail.com","adnan.mehmeti@gmail.com"]
}

# %%
import pandas as pd

# %%
df=pd.DataFrame(personat)

# %%
df
# Out:
#       emri   mbiemri                       email
# 0   Blerta     Hoxha      blerta.hoxha@gmail.com
# 1     Agon    Salihu       agon.salihu@gmail.com
# 2  Bernard  Kastrati  bernard.kastrati@gmail.com
# 3   Arbnor    Hetemi     arbnor.hetemi@gmail.com
# 4   Blerta    Ahmeti     blerta.ahmeti@gmail.com
# 5    Adnan     Lupqi       adnan.lupqi@gmail.com
# 6    Adnan   Mehmeti     adnan.mehmeti@gmail.com

# %%
df['emri']+['mbiemri']
# Out:
# 0     Blertambiemri
# 1       Agonmbiemri
# 2    Bernardmbiemri
# 3     Arbnormbiemri
# 4     Blertambiemri
# 5      Adnanmbiemri
# 6      Adnanmbiemri
# Name: emri, dtype: object

# %%
df['emri'] +' '+ df['mbiemri']
# Out:
# 0        Blerta Hoxha
# 1         Agon Salihu
# 2    Bernard Kastrati
# 3       Arbnor Hetemi
# 4       Blerta Ahmeti
# 5         Adnan Lupqi
# 6       Adnan Mehmeti
# dtype: object

# %%
df['emri_mbiemri_plote'] = df['emri'] + ' ' + df['mbiemri']

# %%
df
# Out:
#       emri   mbiemri                       email emri_mbiemri_plote
# 0   Blerta     Hoxha      blerta.hoxha@gmail.com       Blerta Hoxha
# 1     Agon    Salihu       agon.salihu@gmail.com        Agon Salihu
# 2  Bernard  Kastrati  bernard.kastrati@gmail.com   Bernard Kastrati
# 3   Arbnor    Hetemi     arbnor.hetemi@gmail.com      Arbnor Hetemi
# 4   Blerta    Ahmeti     blerta.ahmeti@gmail.com      Blerta Ahmeti
# 5    Adnan     Lupqi       adnan.lupqi@gmail.com        Adnan Lupqi
# 6    Adnan   Mehmeti     adnan.mehmeti@gmail.com      Adnan Mehmeti

# %%
df.drop(columns=['emri', 'mbiemri'])
# Out:
#                         email emri_mbiemri_plote
# 0      blerta.hoxha@gmail.com       Blerta Hoxha
# 1       agon.salihu@gmail.com        Agon Salihu
# 2  bernard.kastrati@gmail.com   Bernard Kastrati
# 3     arbnor.hetemi@gmail.com      Arbnor Hetemi
# 4     blerta.ahmeti@gmail.com      Blerta Ahmeti
# 5       adnan.lupqi@gmail.com        Adnan Lupqi
# 6     adnan.mehmeti@gmail.com      Adnan Mehmeti

# %%
df['emri_mbiemri_plote'].str.split(' ')
# Out:
# 0        [Blerta, Hoxha]
# 1         [Agon, Salihu]
# 2    [Bernard, Kastrati]
# 3       [Arbnor, Hetemi]
# 4       [Blerta, Ahmeti]
# 5         [Adnan, Lupqi]
# 6       [Adnan, Mehmeti]
# Name: emri_mbiemri_plote, dtype: object

# %%
df['emri_mbiemri_plote'].str.split(' ', expand=True)
# Out:
#          0         1
# 0   Blerta     Hoxha
# 1     Agon    Salihu
# 2  Bernard  Kastrati
# 3   Arbnor    Hetemi
# 4   Blerta    Ahmeti
# 5    Adnan     Lupqi
# 6    Adnan   Mehmeti

# %%
df[['emri', 'mbiemri']]=df['emri_mbiemri_plote'].str.split(' ', expand=True)

# %%
df
# Out:
#       emri   mbiemri                       email emri_mbiemri_plote
# 0   Blerta     Hoxha      blerta.hoxha@gmail.com       Blerta Hoxha
# 1     Agon    Salihu       agon.salihu@gmail.com        Agon Salihu
# 2  Bernard  Kastrati  bernard.kastrati@gmail.com   Bernard Kastrati
# 3   Arbnor    Hetemi     arbnor.hetemi@gmail.com      Arbnor Hetemi
# 4   Blerta    Ahmeti     blerta.ahmeti@gmail.com      Blerta Ahmeti
# 5    Adnan     Lupqi       adnan.lupqi@gmail.com        Adnan Lupqi
# 6    Adnan   Mehmeti     adnan.mehmeti@gmail.com      Adnan Mehmeti

# %%
df.append({'emri':'Ajet'}, ignore_index=True)
# Out:
# /var/folders/3s/g1lyd01905s33dt6txc6jyc00000gn/T/ipykernel_30163/3024760752.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append({'emri':'Ajet'}, ignore_index=True)
#       emri   mbiemri                       email emri_mbiemri_plote
# 0   Blerta     Hoxha      blerta.hoxha@gmail.com       Blerta Hoxha
# 1     Agon    Salihu       agon.salihu@gmail.com        Agon Salihu
# 2  Bernard  Kastrati  bernard.kastrati@gmail.com   Bernard Kastrati
# 3   Arbnor    Hetemi     arbnor.hetemi@gmail.com      Arbnor Hetemi
# 4   Blerta    Ahmeti     blerta.ahmeti@gmail.com      Blerta Ahmeti
# 5    Adnan     Lupqi       adnan.lupqi@gmail.com        Adnan Lupqi
# 6    Adnan   Mehmeti     adnan.mehmeti@gmail.com      Adnan Mehmeti
# 7     Ajet       NaN                         NaN                NaN

# %%
personat = {
    "emri": ["Argjend", "Bekim", "Betim", "Donat"],
    "mbiemri": ["Shala", "Frangu", "Thaqi", "Xerxa"],
    "email": ["argjend.shala@gmail.com", "bekim.frangu@gmail.com", "betim.thaqi@gmail.com", "donar.xerxa@gmail.com"]
}

# %%
df_1=pd.DataFrame(personat)

# %%
df_1
# Out:
#       emri mbiemri                    email
# 0  Argjend   Shala  argjend.shala@gmail.com
# 1    Bekim  Frangu   bekim.frangu@gmail.com
# 2    Betim   Thaqi    betim.thaqi@gmail.com
# 3    Donat   Xerxa    donar.xerxa@gmail.com

# %%
df
# Out:
#       emri   mbiemri                       email emri_mbiemri_plote
# 0   Blerta     Hoxha      blerta.hoxha@gmail.com       Blerta Hoxha
# 1     Agon    Salihu       agon.salihu@gmail.com        Agon Salihu
# 2  Bernard  Kastrati  bernard.kastrati@gmail.com   Bernard Kastrati
# 3   Arbnor    Hetemi     arbnor.hetemi@gmail.com      Arbnor Hetemi
# 4   Blerta    Ahmeti     blerta.ahmeti@gmail.com      Blerta Ahmeti
# 5    Adnan     Lupqi       adnan.lupqi@gmail.com        Adnan Lupqi
# 6    Adnan   Mehmeti     adnan.mehmeti@gmail.com      Adnan Mehmeti

# %%
df_1
# Out:
#       emri mbiemri                    email
# 0  Argjend   Shala  argjend.shala@gmail.com
# 1    Bekim  Frangu   bekim.frangu@gmail.com
# 2    Betim   Thaqi    betim.thaqi@gmail.com
# 3    Donat   Xerxa    donar.xerxa@gmail.com

# %%
df.append(df_1, ignore_index=True)
# Out:
# /var/folders/3s/g1lyd01905s33dt6txc6jyc00000gn/T/ipykernel_30163/2087394683.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(df_1, ignore_index=True)
#        emri   mbiemri                       email emri_mbiemri_plote
# 0    Blerta     Hoxha      blerta.hoxha@gmail.com       Blerta Hoxha
# 1      Agon    Salihu       agon.salihu@gmail.com        Agon Salihu
# 2   Bernard  Kastrati  bernard.kastrati@gmail.com   Bernard Kastrati
# 3    Arbnor    Hetemi     arbnor.hetemi@gmail.com      Arbnor Hetemi
# 4    Blerta    Ahmeti     blerta.ahmeti@gmail.com      Blerta Ahmeti
# 5     Adnan     Lupqi       adnan.lupqi@gmail.com        Adnan Lupqi
# 6     Adnan   Mehmeti     adnan.mehmeti@gmail.com      Adnan Mehmeti
# 7   Argjend     Shala     argjend.shala@gmail.com                NaN
# 8     Bekim    Frangu      bekim.frangu@gmail.com                NaN
# ...

# %%
df.append(df_1, ignore_index=True, sort=False)
# Out:
# /var/folders/3s/g1lyd01905s33dt6txc6jyc00000gn/T/ipykernel_30163/3704488222.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(df_1, ignore_index=True, sort=False)
#        emri   mbiemri                       email emri_mbiemri_plote
# 0    Blerta     Hoxha      blerta.hoxha@gmail.com       Blerta Hoxha
# 1      Agon    Salihu       agon.salihu@gmail.com        Agon Salihu
# 2   Bernard  Kastrati  bernard.kastrati@gmail.com   Bernard Kastrati
# 3    Arbnor    Hetemi     arbnor.hetemi@gmail.com      Arbnor Hetemi
# 4    Blerta    Ahmeti     blerta.ahmeti@gmail.com      Blerta Ahmeti
# 5     Adnan     Lupqi       adnan.lupqi@gmail.com        Adnan Lupqi
# 6     Adnan   Mehmeti     adnan.mehmeti@gmail.com      Adnan Mehmeti
# 7   Argjend     Shala     argjend.shala@gmail.com                NaN
# 8     Bekim    Frangu      bekim.frangu@gmail.com                NaN
# ...

# %%
df.append(df_1, ignore_index=True, sort=True)
# Out:
# /var/folders/3s/g1lyd01905s33dt6txc6jyc00000gn/T/ipykernel_30163/2690422381.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(df_1, ignore_index=True, sort=True)
#                          email     emri emri_mbiemri_plote   mbiemri
# 0       blerta.hoxha@gmail.com   Blerta       Blerta Hoxha     Hoxha
# 1        agon.salihu@gmail.com     Agon        Agon Salihu    Salihu
# 2   bernard.kastrati@gmail.com  Bernard   Bernard Kastrati  Kastrati
# 3      arbnor.hetemi@gmail.com   Arbnor      Arbnor Hetemi    Hetemi
# 4      blerta.ahmeti@gmail.com   Blerta      Blerta Ahmeti    Ahmeti
# 5        adnan.lupqi@gmail.com    Adnan        Adnan Lupqi     Lupqi
# 6      adnan.mehmeti@gmail.com    Adnan      Adnan Mehmeti   Mehmeti
# 7      argjend.shala@gmail.com  Argjend                NaN     Shala
# 8       bekim.frangu@gmail.com    Bekim                NaN    Frangu
# ...

# %%
df.append(df_1, ignore_index=True, sort=False)
# Out:
# /var/folders/3s/g1lyd01905s33dt6txc6jyc00000gn/T/ipykernel_30163/3704488222.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(df_1, ignore_index=True, sort=False)
#        emri   mbiemri                       email emri_mbiemri_plote
# 0    Blerta     Hoxha      blerta.hoxha@gmail.com       Blerta Hoxha
# 1      Agon    Salihu       agon.salihu@gmail.com        Agon Salihu
# 2   Bernard  Kastrati  bernard.kastrati@gmail.com   Bernard Kastrati
# 3    Arbnor    Hetemi     arbnor.hetemi@gmail.com      Arbnor Hetemi
# 4    Blerta    Ahmeti     blerta.ahmeti@gmail.com      Blerta Ahmeti
# 5     Adnan     Lupqi       adnan.lupqi@gmail.com        Adnan Lupqi
# 6     Adnan   Mehmeti     adnan.mehmeti@gmail.com      Adnan Mehmeti
# 7   Argjend     Shala     argjend.shala@gmail.com                NaN
# 8     Bekim    Frangu      bekim.frangu@gmail.com                NaN
# ...

# %%
df.drop(index=6)
# Out:
#       emri   mbiemri                       email emri_mbiemri_plote
# 0   Blerta     Hoxha      blerta.hoxha@gmail.com       Blerta Hoxha
# 1     Agon    Salihu       agon.salihu@gmail.com        Agon Salihu
# 2  Bernard  Kastrati  bernard.kastrati@gmail.com   Bernard Kastrati
# 3   Arbnor    Hetemi     arbnor.hetemi@gmail.com      Arbnor Hetemi
# 4   Blerta    Ahmeti     blerta.ahmeti@gmail.com      Blerta Ahmeti
# 5    Adnan     Lupqi       adnan.lupqi@gmail.com        Adnan Lupqi

# %%
df.drop(index=df[df['emri']=='Arbnor'].index)
# Out:
#       emri   mbiemri                       email emri_mbiemri_plote
# 0   Blerta     Hoxha      blerta.hoxha@gmail.com       Blerta Hoxha
# 1     Agon    Salihu       agon.salihu@gmail.com        Agon Salihu
# 2  Bernard  Kastrati  bernard.kastrati@gmail.com   Bernard Kastrati
# 4   Blerta    Ahmeti     blerta.ahmeti@gmail.com      Blerta Ahmeti
# 5    Adnan     Lupqi       adnan.lupqi@gmail.com        Adnan Lupqi
# 6    Adnan   Mehmeti     adnan.mehmeti@gmail.com      Adnan Mehmeti

# %%
filt=df['emri'] == 'Agon'

# %%
df.drop(index=df[filt].index)
# Out:
#       emri   mbiemri                       email emri_mbiemri_plote
# 0   Blerta     Hoxha      blerta.hoxha@gmail.com       Blerta Hoxha
# 2  Bernard  Kastrati  bernard.kastrati@gmail.com   Bernard Kastrati
# 3   Arbnor    Hetemi     arbnor.hetemi@gmail.com      Arbnor Hetemi
# 4   Blerta    Ahmeti     blerta.ahmeti@gmail.com      Blerta Ahmeti
# 5    Adnan     Lupqi       adnan.lupqi@gmail.com        Adnan Lupqi
# 6    Adnan   Mehmeti     adnan.mehmeti@gmail.com      Adnan Mehmeti

# %%
df
# Out:
#       emri   mbiemri                       email emri_mbiemri_plote
# 0   Blerta     Hoxha      blerta.hoxha@gmail.com       Blerta Hoxha
# 1     Agon    Salihu       agon.salihu@gmail.com        Agon Salihu
# 2  Bernard  Kastrati  bernard.kastrati@gmail.com   Bernard Kastrati
# 3   Arbnor    Hetemi     arbnor.hetemi@gmail.com      Arbnor Hetemi
# 4   Blerta    Ahmeti     blerta.ahmeti@gmail.com      Blerta Ahmeti
# 5    Adnan     Lupqi       adnan.lupqi@gmail.com        Adnan Lupqi
# 6    Adnan   Mehmeti     adnan.mehmeti@gmail.com      Adnan Mehmeti

# %%
df.sort_values(by='emri')
# Out:
#       emri   mbiemri                       email emri_mbiemri_plote
# 5    Adnan     Lupqi       adnan.lupqi@gmail.com        Adnan Lupqi
# 6    Adnan   Mehmeti     adnan.mehmeti@gmail.com      Adnan Mehmeti
# 1     Agon    Salihu       agon.salihu@gmail.com        Agon Salihu
# 3   Arbnor    Hetemi     arbnor.hetemi@gmail.com      Arbnor Hetemi
# 2  Bernard  Kastrati  bernard.kastrati@gmail.com   Bernard Kastrati
# 0   Blerta     Hoxha      blerta.hoxha@gmail.com       Blerta Hoxha
# 4   Blerta    Ahmeti     blerta.ahmeti@gmail.com      Blerta Ahmeti

# %%
df.sort_values(by='mbiemri')
# Out:
#       emri   mbiemri                       email emri_mbiemri_plote
# 4   Blerta    Ahmeti     blerta.ahmeti@gmail.com      Blerta Ahmeti
# 3   Arbnor    Hetemi     arbnor.hetemi@gmail.com      Arbnor Hetemi
# 0   Blerta     Hoxha      blerta.hoxha@gmail.com       Blerta Hoxha
# 2  Bernard  Kastrati  bernard.kastrati@gmail.com   Bernard Kastrati
# 5    Adnan     Lupqi       adnan.lupqi@gmail.com        Adnan Lupqi
# 6    Adnan   Mehmeti     adnan.mehmeti@gmail.com      Adnan Mehmeti
# 1     Agon    Salihu       agon.salihu@gmail.com        Agon Salihu

# %%
df.sort_values(by=['emri'], ascending=False)
# Out:
#       emri   mbiemri                       email emri_mbiemri_plote
# 0   Blerta     Hoxha      blerta.hoxha@gmail.com       Blerta Hoxha
# 4   Blerta    Ahmeti     blerta.ahmeti@gmail.com      Blerta Ahmeti
# 2  Bernard  Kastrati  bernard.kastrati@gmail.com   Bernard Kastrati
# 3   Arbnor    Hetemi     arbnor.hetemi@gmail.com      Arbnor Hetemi
# 1     Agon    Salihu       agon.salihu@gmail.com        Agon Salihu
# 5    Adnan     Lupqi       adnan.lupqi@gmail.com        Adnan Lupqi
# 6    Adnan   Mehmeti     adnan.mehmeti@gmail.com      Adnan Mehmeti

# %%
df.sort_values(by=['emri','mbiemri'], ascending=False)
# Out:
#       emri   mbiemri                       email emri_mbiemri_plote
# 0   Blerta     Hoxha      blerta.hoxha@gmail.com       Blerta Hoxha
# 4   Blerta    Ahmeti     blerta.ahmeti@gmail.com      Blerta Ahmeti
# 2  Bernard  Kastrati  bernard.kastrati@gmail.com   Bernard Kastrati
# 3   Arbnor    Hetemi     arbnor.hetemi@gmail.com      Arbnor Hetemi
# 1     Agon    Salihu       agon.salihu@gmail.com        Agon Salihu
# 6    Adnan   Mehmeti     adnan.mehmeti@gmail.com      Adnan Mehmeti
# 5    Adnan     Lupqi       adnan.lupqi@gmail.com        Adnan Lupqi

# %%
df.sort_values(by=['emri','mbiemri'], ascending=[True, False])
# Out:
#       emri   mbiemri                       email emri_mbiemri_plote
# 6    Adnan   Mehmeti     adnan.mehmeti@gmail.com      Adnan Mehmeti
# 5    Adnan     Lupqi       adnan.lupqi@gmail.com        Adnan Lupqi
# 1     Agon    Salihu       agon.salihu@gmail.com        Agon Salihu
# 3   Arbnor    Hetemi     arbnor.hetemi@gmail.com      Arbnor Hetemi
# 2  Bernard  Kastrati  bernard.kastrati@gmail.com   Bernard Kastrati
# 0   Blerta     Hoxha      blerta.hoxha@gmail.com       Blerta Hoxha
# 4   Blerta    Ahmeti     blerta.ahmeti@gmail.com      Blerta Ahmeti

# %%
df.sort_values(by=['emri','mbiemri'], ascending=[True, False], inplace=True)

# %%
df
# Out:
#       emri   mbiemri                       email emri_mbiemri_plote
# 6    Adnan   Mehmeti     adnan.mehmeti@gmail.com      Adnan Mehmeti
# 5    Adnan     Lupqi       adnan.lupqi@gmail.com        Adnan Lupqi
# 1     Agon    Salihu       agon.salihu@gmail.com        Agon Salihu
# 3   Arbnor    Hetemi     arbnor.hetemi@gmail.com      Arbnor Hetemi
# 2  Bernard  Kastrati  bernard.kastrati@gmail.com   Bernard Kastrati
# 0   Blerta     Hoxha      blerta.hoxha@gmail.com       Blerta Hoxha
# 4   Blerta    Ahmeti     blerta.ahmeti@gmail.com      Blerta Ahmeti

# %%
df
# Out:
#       emri   mbiemri                       email emri_mbiemri_plote
# 6    Adnan   Mehmeti     adnan.mehmeti@gmail.com      Adnan Mehmeti
# 5    Adnan     Lupqi       adnan.lupqi@gmail.com        Adnan Lupqi
# 1     Agon    Salihu       agon.salihu@gmail.com        Agon Salihu
# 3   Arbnor    Hetemi     arbnor.hetemi@gmail.com      Arbnor Hetemi
# 2  Bernard  Kastrati  bernard.kastrati@gmail.com   Bernard Kastrati
# 0   Blerta     Hoxha      blerta.hoxha@gmail.com       Blerta Hoxha
# 4   Blerta    Ahmeti     blerta.ahmeti@gmail.com      Blerta Ahmeti

# %%
df.sort_index(inplace=True)

# %%
df
# Out:
#       emri   mbiemri                       email emri_mbiemri_plote
# 0   Blerta     Hoxha      blerta.hoxha@gmail.com       Blerta Hoxha
# 1     Agon    Salihu       agon.salihu@gmail.com        Agon Salihu
# 2  Bernard  Kastrati  bernard.kastrati@gmail.com   Bernard Kastrati
# 3   Arbnor    Hetemi     arbnor.hetemi@gmail.com      Arbnor Hetemi
# 4   Blerta    Ahmeti     blerta.ahmeti@gmail.com      Blerta Ahmeti
# 5    Adnan     Lupqi       adnan.lupqi@gmail.com        Adnan Lupqi
# 6    Adnan   Mehmeti     adnan.mehmeti@gmail.com      Adnan Mehmeti

# %%
df
# Out:
#       emri   mbiemri                       email emri_mbiemri_plote
# 6    Adnan   Mehmeti     adnan.mehmeti@gmail.com      Adnan Mehmeti
# 5    Adnan     Lupqi       adnan.lupqi@gmail.com        Adnan Lupqi
# 1     Agon    Salihu       agon.salihu@gmail.com        Agon Salihu
# 3   Arbnor    Hetemi     arbnor.hetemi@gmail.com      Arbnor Hetemi
# 2  Bernard  Kastrati  bernard.kastrati@gmail.com   Bernard Kastrati
# 0   Blerta     Hoxha      blerta.hoxha@gmail.com       Blerta Hoxha
# 4   Blerta    Ahmeti     blerta.ahmeti@gmail.com      Blerta Ahmeti

# %%
df['emri_mbiemri_plote'].sort_values()
# Out:
# 5         Adnan Lupqi
# 6       Adnan Mehmeti
# 1         Agon Salihu
# 3       Arbnor Hetemi
# 2    Bernard Kastrati
# 4       Blerta Ahmeti
# 0        Blerta Hoxha
# Name: emri_mbiemri_plote, dtype: object
